# %% [markdown]
# ### Star Schema

# %%
from PIL import Image
import requests
import matplotlib.pyplot as plt

# Corrigir import do star schema
url = 'https://i.imgur.com/1prxQ4H.png'
response = requests.get(url, stream=True)
img = Image.open(response.raw)

plt.imshow(img)
plt.show()

# %% [markdown]
# ### Importação dos datasets relevantes ao problema
#
# Datasets a importar:
# * US Accidents
# * TMC's e eventos associados
# * Calendário com fases da lua (\*)
# * Limite máximo de velocidade por estado
# * Dados de consumo de álcool por estado
# * Quantidade de automóveis registados por estado

# %%
import numpy as np
import pandas as pd
import re
import datetime as dt

# %% [markdown]
# ##### Importação do dataset US Accidents

# %%
def generate_sample(filename, s):
    n = np.sum([1 for _ in open(filename)]) - 1 # number of records in file (excludes header)
    indices = np.arange(1, n + 1)
    skip = np.sort(np.random.choice(indices, size=n - s, replace=False)) # random indices to skip

    return pd.read_csv(filename, skiprows=skip)

# %%
# import US accidents dataset
#us_acidents = pd.read_csv('US_Accidents_Dec19.csv')
us_acidents = generate_sample('US_Accidents_Dec19.csv', 50000)

us_acidents.head(5)
# Out:
#       ID         Source    TMC  Severity           Start_Time  \
# 0  A-205       MapQuest  406.0         3  2016-02-16 16:47:00
# 1  A-213       MapQuest  201.0         3  2016-02-17 07:22:56
# 2  A-266       MapQuest  201.0         2  2016-02-18 15:46:33
# 3  A-308  MapQuest-Bing  201.0         3  2016-02-22 07:24:22
# 4  A-311       MapQuest  201.0         2  2016-02-22 07:51:22
#
#               End_Time  Start_Lat  Start_Lng  End_Lat  End_Lng  ...  \
# 0  2016-02-16 21:00:00  40.016014 -82.903442      NaN      NaN  ...
# 1  2016-02-17 07:52:56  41.063995 -81.572945      NaN      NaN  ...
# 2  2016-02-18 16:31:33  39.759544 -84.191811      NaN      NaN  ...
# 3  2016-02-22 07:54:22  39.933804 -82.789444      NaN      NaN  ...
# 4  2016-02-22 08:21:22  39.772438 -84.142181      NaN      NaN  ...
#
#    Roundabout Station   Stop Traffic_Calming Traffic_Signal Turning_Loop  \
# 0       False   False  False           False          False        False
# 1       False   False  False           False          False        False
# 2       False   False  False           False          False        False
# 3       False   False  False           False          False        False
# 4       False   False  False           False          False        False
#
#   Sunrise_Sunset Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Day            Day               Day                   Day
# 1            Day            Day               Day                   Day
# 2            Day            Day               Day                   Day
# 3            Day            Day               Day                   Day
# 4            Day            Day               Day                   Day
#
# [5 rows x 49 columns]

# %% [markdown]
# ##### Importação do dataset relativo a TMCs / Criação da Dimensão TMC

# %%
# import event codes
event_code = pd.read_csv('event_code_tmc.csv', delimiter=';')
event_code = event_code.rename(columns={"Code": "TMC_Key", "Description":"Event"})

# add out-of-range key
event_code = event_code.append({'TMC_Key': -1, 'Event': 'unidentified'}, ignore_index=True)
event_code.head(5)
# Out:
#    TMC_Key                                              Event
# 0        1                                    traffic problem
# 1        2  queuing traffic (with average speeds Q). Dange...
# 2       11                overheight warning system triggered
# 3       12  (Q) accident(s), traffic being directed around...
# 4       16       closed, rescue and recovery work in progress

# %% [markdown]
# ##### Importação do dataset sobre consumo de álcool

# %%
def discretize_rate(x):
    if x <= 2.0:
        return 'Low'
    elif 2.0 < x <= 2.5:
        return 'Medium'
    elif 2.5 < x <= 3.5:
        return 'High'
    else:
        return 'Very High'

# import alcohool consumption rates by state
alcohol_consumption = pd.read_csv('alcohol_consumption_state.csv', delimiter=';')

alcohol_consumption.at[20, "State"] = "Massachusetts"

# sort and reset index
alcohol_consumption = alcohol_consumption.sort_values(by=['rate'], ascending=False).reset_index(drop=True)

alcohol_consumption['DiscreteRate'] = alcohol_consumption['rate'].map(discretize_rate)

alcohol_dict = pd.Series(alcohol_consumption['DiscreteRate'].values, index=alcohol_consumption['State']).to_dict()
alcohol_dict
# Out:
# {'New Hampshire': 'Very High',
#  'Delaware': 'Very High',
#  'Nevada': 'High',
#  'North Dakota': 'High',
#  'Montana': 'High',
#  'Vermont': 'High',
#  'Wisconsin': 'High',
#  'Idaho': 'High',
#  'South Dakota': 'High',
#  'Colorado': 'High',
#  'Maine': 'High',
#  'Alaska': 'High',
#  'Minnesota': 'High',
#  'Oregon': 'High',
#  'Wyoming': 'High',
#  'Hawaii': 'High',
#  'Florida': 'High',
#  'Rhode Island': 'High',
#  'Massachusetts': 'High',
#  'Louisiana': 'High',
#  'Missouri': 'High',
#  'Connecticut': 'Medium',
#  'Iowa': 'Medium',
#  'Illinois': 'Medium',
#  'Texas': 'Medium',
#  'Pennsylvania': 'Medium',
#  'Michigan': 'Medium',
#  'New Jersey': 'Medium',
#  'California': 'Medium',
#  'Arizona': 'Medium',
#  'Washington': 'Medium',
#  'Nebraska': 'Medium',
#  'Mississippi': 'Medium',
#  'New York': 'Medium',
#  'South Carolina': 'Medium',
#  'New Mexico': 'Medium',
#  'North Carolina': 'Medium',
#  'Maryland': 'Medium',
#  'Virginia': 'Medium',
#  'Indiana': 'Medium',
#  'Tennessee': 'Medium',
#  'Ohio': 'Medium',
#  'Alabama': 'Low',
#  'Kentucky': 'Low',
#  'Kansas': 'Low',
#  'Georgia': 'Low',
#  'Oklahoma': 'Low',
#  'Arkansas': 'Low',
#  'West Virginia': 'Low',
#  'Utah': 'Low'}

# %% [markdown]
# ##### Importação do dataset sobre registos automóveis

# %%
def discretize_total(x):
    if x <= 5000000:
        return 'Low'
    elif 5000000 < x <= 10000000:
        return 'Medium'
    elif 10000000 < x <= 20000000:
        return 'High'
    else:
        return 'Very High'

# import vehicle registrations by state
vehicle_registration = pd.read_csv('vehicle_registrations_usa.csv', delimiter=';')
# filter out non States
vehicle_registration = vehicle_registration[vehicle_registration['State'] != 'Dist. of Col.']

vehicle_registration['Total'] = vehicle_registration['Total'].map(lambda x: int(re.sub(' ', '', x)))

# sort and reset index
vehicle_registration = vehicle_registration.sort_values(by=['Total'], ascending=False).reset_index(drop=True)

vehicle_registration['DiscreteTotal'] = vehicle_registration['Total'].map(discretize_total)

vehicle_dict = pd.Series(vehicle_registration['DiscreteTotal'].values, index=vehicle_registration['State']).to_dict()
vehicle_dict
# Out:
# {'California ': 'Very High',
#  'Texas': 'Very High',
#  'Florida': 'High',
#  'New York': 'High',
#  'Ohio': 'High',
#  'Pennsylvania': 'High',
#  'Illinois': 'High',
#  'Georgia': 'Medium',
#  'Michigan': 'Medium',
#  'North Carolina': 'Medium',
#  'Virginia': 'Medium',
#  'Washington': 'Medium',
#  'Indiana': 'Medium',
#  'New Jersey': 'Medium',
#  'Arizona': 'Medium',
#  'Tennessee': 'Medium',
#  'Wisconsin': 'Medium',
#  'Missouri': 'Medium',
#  'Minnesota': 'Medium',
#  'Colorado': 'Medium',
#  'Alabama': 'Medium',
#  'Massachusetts': 'Medium',
#  'South Carolina': 'Low',
#  'Kentucky': 'Low',
#  'Maryland': 'Low',
#  'Oregon': 'Low',
#  'Louisiana': 'Low',
#  'Oklahoma': 'Low',
#  'Iowa': 'Low',
#  'Connecticut ': 'Low',
#  'Arkansas': 'Low',
#  'Kansas': 'Low',
#  'Nevada': 'Low',
#  'Utah': 'Low',
#  'Mississippi': 'Low',
#  'Nebraska': 'Low',
#  'Idaho': 'Low',
#  'Montana': 'Low',
#  'New Mexico': 'Low',
#  'West Virginia': 'Low',
#  'New Hampshire': 'Low',
#  'South Dakota': 'Low',
#  'Hawaii': 'Low',
#  'Maine': 'Low',
#  'Delaware': 'Low',
#  'North Dakota': 'Low',
#  'Rhode Island': 'Low',
#  'Wyoming': 'Low',
#  'Alaska': 'Low',
#  'Vermont': 'Low'}

# %% [markdown]
# ##### Importação do dataset sobre nível de urbanização

# %%
# import rural/urban information about counties
urban = pd.read_excel('NCHSURCodes2013.xlsx')

# drop unwanted information
urban = urban.drop(['State Abr.','CBSA title', 'CBSA 2012 pop', 'County 2012 pop'], axis=1)

# remove County from name
urban['County name'] = urban['County name'].map(lambda x: re.sub(' County', '', x))

urban_term = {1:'Large Central Metro',
              2:'Large Fringe Metro',
              3:'Medium Metro',
              4:'Small Metro',
              5:'Micropolitan',
              6:'Non-Core'}

urban["2013 code"] = urban["2013 code"].map(urban_term)

urban_dict = pd.Series(urban['2013 code'].values, index=urban['County name']).to_dict()
urban_dict
# Out:
# {'Autauga': 'Medium Metro',
#  'Baldwin': 'Micropolitan',
#  'Barbour': 'Non-Core',
#  'Bibb': 'Small Metro',
#  'Blount': 'Medium Metro',
#  'Bullock': 'Non-Core',
#  'Butler': 'Large Fringe Metro',
#  'Calhoun': 'Non-Core',
#  'Chambers': 'Large Fringe Metro',
#  'Cherokee': 'Micropolitan',
#  'Chilton': 'Large Fringe Metro',
#  'Choctaw': 'Non-Core',
#  'Clarke': 'Large Fringe Metro',
#  'Clay': 'Small Metro',
#  'Cleburne': 'Non-Core',
#  'Coffee': 'Micropolitan',
#  'Colbert': 'Small Metro',
#  'Conecuh': 'Non-Core',
#  'Coosa': 'Micropolitan',
#  'Covington': 'Non-Core',
#  'Crenshaw': 'Non-Core',
#  'Cullman': 'Micropolitan',
#  'Dale': 'Micropolitan',
#  'Dallas': 'Large Central Metro',
#  'DeKalb': 'Non-Core',
#  'Elmore': 'Micropolitan',
#  'Escambia': 'Medium Metro',
#  'Etowah': 'Small Metro',
#  'Fayette': 'Small Metro',
#  'Franklin': 'Medium Metro',
#  'Geneva': 'Small Metro',
#  'Greene': 'Small Metro',
#  'Hale': 'Micropolitan',
#  'Henry': 'Micropolitan',
#  'Houston': 'Non-Core',
#  'Jackson': 'Non-Core',
#  'Jefferson': 'Micropolitan',
#  'Lamar': 'Micropolitan',
#  'Lauderdale': 'Non-Core',
#  'Lawrence': 'Micropolitan',
#  'Lee': 'Non-Core',
#  'Limestone': 'Non-Core',
#  'Lowndes': 'Micropolitan',
#  'Macon': 'Large Fringe Metro',
#  'Madison': 'Non-Core',
#  'Marengo': 'Non-Core',
#  'Marion': 'Micropolitan',
#  'Marshall': 'Small Metro',
#  'Mobile': 'Medium Metro',
#  'Monroe': 'Non-Core',
#  'Montgomery': 'Small Metro',
#  'Morgan': 'Non-Core',
#  'Perry': 'Non-Core',
#  'Pickens': 'Medium Metro',
#  'Pike': 'Large Fringe Metro',
#  'Randolph': 'Micropolitan',
#  'Russell': 'Non-Core',
#  'St. Clair': 'Non-Core',
#  'Shelby': 'Non-Core',
#  'Sumter': 'Small Metro',
#  'Talladega': 'Micropolitan',
#  'Tallapoosa': 'Non-Core',
#  'Tuscaloosa': 'Small Metro',
#  'Walker': 'Micropolitan',
#  'Washington': 'Large Fringe Metro',
#  'Wilcox': 'Non-Core',
#  'Winston': 'Non-Core',
#  'Aleutians East Borough': 'Non-Core',
#  'Aleutians West Census Area': 'Non-Core',
#  'Anchorage Municipality': 'Medium Metro',
#  'Bethel Census Area': 'Non-Core',
#  'Bristol Bay Borough': 'Non-Core',
#  'Denali Borough': 'Non-Core',
#  'Dillingham Census Area': 'Non-Core',
#  'Fairbanks North Star Borough': 'Small Metro',
#  'Haines Borough': 'Non-Core',
#  'Hoonah-Angoon Census Area': 'Non-Core',
#  'Juneau City and Borough': 'Micropolitan',
#  'Kenai Peninsula Borough': 'Non-Core',
#  'Ketchikan Gateway Borough': 'Micropolitan',
#  'Kodiak Island Borough': 'Non-Core',
#  'Kusilvak Census Area': 'Non-Core',
#  'Lake and Peninsula Borough': 'Non-Core',
#  'Matanuska-Susitna Borough': 'Medium Metro',
#  'Nome Census Area': 'Non-Core',
#  'North Slope Borough': 'Non-Core',
#  'Northwest Arctic Borough': 'Non-Core',
#  'Petersburg Census Area': 'Non-Core',
#  'Prince of Wales-Hyder Census Area': 'Non-Core',
#  'Prince of Wales-Outer Ket': 'Non-Core',
#  'Sitka City and Borough': 'Non-Core',
#  'Skagway Municipality': 'Non-Core',
#  'Skagway-Hoonah-Angoon Census Area': 'Non-Core',
#  'Southeast Fairbanks Census Area': 'Non-Core',
#  'Valdez-Cordova Census Area': 'Non-Core',
#  'Wade Hampton Census Area': 'Non-Core',
#  'Wrangell City and Borough': 'Non-Core',
#  'Wrangell-Petersburg Census Area': 'Non-Core',
#  'Yakutat City and Borough': 'Non-Core',
#  'Yukon-Koyukuk Census Area': 'Non-Core',
#  'Apache': 'Non-Core',
#  'Cochise': 'Small Metro',
#  'Coconino': 'Small Metro',
#  'Gila': 'Micropolitan',
#  'Graham': 'Non-Core',
#  'Greenlee': 'Non-Core',
#  'La Paz': 'Non-Core',
#  'Maricopa': 'Large Central Metro',
#  'Mohave': 'Small Metro',
#  'Navajo': 'Micropolitan',
#  'Pima': 'Medium Metro',
#  'Pinal': 'Large Fringe Metro',
#  'Santa Cruz': 'Medium Metro',
#  'Yavapai': 'Small Metro',
#  'Yuma': 'Non-Core',
#  'Arkansas': 'Non-Core',
#  'Ashley': 'Non-Core',
#  'Baxter': 'Micropolitan',
#  'Benton': 'Medium Metro',
#  'Boone': 'Small Metro',
#  'Bradley': 'Small Metro',
#  'Carroll': 'Non-Core',
#  'Chicot': 'Non-Core',
#  'Clark': 'Non-Core',
#  'Cleveland': 'Large Fringe Metro',
#  'Columbia': 'Medium Metro',
#  'Conway': 'Non-Core',
#  'Craighead': 'Small Metro',
#  'Crawford': 'Non-Core',
#  'Crittenden': 'Non-Core',
#  'Cross': 'Non-Core',
#  'Desha': 'Non-Core',
#  'Drew': 'Non-Core',
#  'Faulkner': 'Medium Metro',
#  'Fulton': 'Non-Core',
#  'Garland': 'Small Metro',
#  'Grant': 'Micropolitan',
#  'Hempstead': 'Non-Core',
#  'Hot Spring': 'Micropolitan',
#  'Howard': 'Micropolitan',
#  'Independence': 'Micropolitan',
#  'Izard': 'Non-Core',
#  'Johnson': 'Non-Core',
#  'Lafayette': 'Non-Core',
#  'Lincoln': 'Non-Core',
#  'Little River': 'Small Metro',
#  'Logan': 'Micropolitan',
#  'Lonoke': 'Medium Metro',
#  'Miller': 'Non-Core',
#  'Mississippi': 'Non-Core',
#  'Nevada': 'Micropolitan',
#  'Newton': 'Medium Metro',
#  'Ouachita': 'Micropolitan',
#  'Phillips': 'Non-Core',
#  'Poinsett': 'Small Metro',
#  'Polk': 'Non-Core',
#  'Pope': 'Non-Core',
#  'Prairie': 'Non-Core',
#  'Pulaski': 'Small Metro',
#  'St. Francis': 'Micropolitan',
#  'Saline': 'Non-Core',
#  'Scott': 'Medium Metro',
#  'Searcy': 'Non-Core',
#  'Sebastian': 'Medium Metro',
#  'Sevier': 'Non-Core',
#  'Sharp': 'Non-Core',
#  'Stone': 'Micropolitan',
#  'Union': 'Medium Metro',
#  'Van Buren': 'Non-Core',
#  'White': 'Non-Core',
#  'Woodruff': 'Non-Core',
#  'Yell': 'Micropolitan',
#  'Alameda': 'Large Central Metro',
#  'Alpine': 'Non-Core',
#  'Amador': 'Non-Core',
#  'Butte': 'Non-Core',
#  'Calaveras': 'Non-Core',
#  'Colusa': 'Non-Core',
#  'Contra Costa': 'Large Fringe Metro',
#  'Del Norte': 'Micropolitan',
#  'El Dorado': 'Large Fringe Metro',
#  'Fresno': 'Medium Metro',
#  'Glenn': 'Non-Core',
#  'Humboldt': 'Micropolitan',
#  'Imperial': 'Small Metro',
#  'Inyo': 'Non-Core',
#  'Kern': 'Medium Metro',
#  'Kings': 'Large Central Metro',
#  'Lake': 'Non-Core',
#  'Lassen': 'Micropolitan',
#  'Los Angeles': 'Large Central Metro',
#  'Madera': 'Small Metro',
#  'Marin': 'Large Fringe Metro',
#  'Mariposa': 'Non-Core',
#  'Mendocino': 'Micropolitan',
#  'Merced': 'Medium Metro',
#  'Modoc': 'Non-Core',
#  'Mono': 'Non-Core',
#  'Monterey': 'Medium Metro',
#  'Napa': 'Small Metro',
#  'Orange': 'Non-Core',
#  'Placer': 'Large Fringe Metro',
#  'Plumas': 'Non-Core',
#  'Riverside': 'Large Central Metro',
#  'Sacramento': 'Large Central Metro',
#  'San Benito': 'Large Fringe Metro',
#  'San Bernardino': 'Large Fringe Metro',
#  'San Diego': 'Large Central Metro',
#  'San Francisco': 'Large Central Metro',
#  'San Joaquin': 'Medium Metro',
#  'San Luis Obispo': 'Medium Metro',
#  'San Mateo': 'Large Fringe Metro',
#  'Santa Barbara': 'Medium Metro',
#  'Santa Clara': 'Large Central Metro',
#  'Shasta': 'Small Metro',
#  'Sierra': 'Non-Core',
#  'Siskiyou': 'Non-Core',
#  'Solano': 'Medium Metro',
#  'Sonoma': 'Medium Metro',
#  'Stanislaus': 'Medium Metro',
#  'Sutter': 'Small Metro',
#  'Tehama': 'Micropolitan',
#  'Trinity': 'Micropolitan',
#  'Tulare': 'Medium Metro',
#  'Tuolumne': 'Micropolitan',
#  'Ventura': 'Medium Metro',
#  'Yolo': 'Large Fringe Metro',
#  'Yuba': 'Small Metro',
#  'Adams': 'Non-Core',
#  'Alamosa': 'Non-Core',
#  'Arapahoe': 'Large Fringe Metro',
#  'Archuleta': 'Non-Core',
#  'Baca': 'Non-Core',
#  'Bent': 'Non-Core',
#  'Boulder': 'Medium Metro',
#  'Broomfield': 'Large Fringe Metro',
#  'Chaffee': 'Non-Core',
#  'Cheyenne': 'Non-Core',
#  'Clear Creek': 'Large Fringe Metro',
#  'Conejos': 'Non-Core',
#  'Costilla': 'Non-Core',
#  'Crowley': 'Non-Core',
#  'Custer': 'Small Metro',
#  'Delta': 'Non-Core',
#  'Denver': 'Large Central Metro',
#  'Dolores': 'Non-Core',
#  'Douglas': 'Medium Metro',
#  'Eagle': 'Micropolitan',
#  'Elbert': 'Non-Core',
#  'El Paso': 'Medium Metro',
#  'Fremont': 'Micropolitan',
#  'Garfield': 'Non-Core',
#  'Gilpin': 'Large Fringe Metro',
#  'Grand': 'Non-Core',
#  'Gunnison': 'Non-Core',
#  'Hinsdale': 'Non-Core',
#  'Huerfano': 'Non-Core',
#  'Kiowa': 'Non-Core',
#  'Kit Carson': 'Non-Core',
#  'La Plata': 'Micropolitan',
#  'Larimer': 'Medium Metro',
#  'Las Animas': 'Non-Core',
#  'Mesa': 'Small Metro',
#  'Mineral': 'Small Metro',
#  'Moffat': 'Micropolitan',
#  'Montezuma': 'Non-Core',
#  'Montrose': 'Micropolitan',
#  'Otero': 'Micropolitan',
#  'Ouray': 'Non-Core',
#  'Park': 'Non-Core',
#  'Pitkin': 'Micropolitan',
#  'Prowers': 'Non-Core',
#  'Pueblo': 'Small Metro',
#  'Rio Blanco': 'Non-Core',
#  'Rio Grande': 'Non-Core',
#  'Routt': 'Micropolitan',
#  'Saguache': 'Non-Core',
#  'San Juan': 'Non-Core',
#  'San Miguel': 'Micropolitan',
#  'Sedgwick': 'Medium Metro',
#  'Summit': 'Micropolitan',
#  'Teller': 'Medium Metro',
#  'Weld': 'Medium Metro',
#  'Fairfield': 'Medium Metro',
#  'Hartford': 'Large Central Metro',
#  'Litchfield': 'Micropolitan',
#  'Middlesex': 'Non-Core',
#  'New Haven': 'Medium Metro',
#  'New London': 'Medium Metro',
#  'Tolland': 'Large Fringe Metro',
#  'Windham': 'Non-Core',
#  'Kent': 'Non-Core',
#  'New Castle': 'Large Fringe Metro',
#  'Sussex': 'Large Fringe Metro',
#  'District of Columbia': 'Large Central Metro',
#  'Alachua': 'Medium Metro',
#  'Baker': 'Non-Core',
#  'Bay': 'Small Metro',
#  'Bradford': 'Micropolitan',
#  'Brevard': 'Medium Metro',
#  'Broward': 'Large Fringe Metro',
#  'Charlotte': 'Non-Core',
#  'Citrus': 'Small Metro',
#  'Collier': 'Medium Metro',
#  'DeSoto': 'Large Fringe Metro',
#  'Dixie': 'Non-Core',
#  'Duval': 'Non-Core',
#  'Flagler': 'Medium Metro',
#  'Gadsden': 'Medium Metro',
#  'Gilchrist': 'Medium Metro',
#  'Glades': 'Non-Core',
#  'Gulf': 'Small Metro',
#  'Hamilton': 'Non-Core',
#  'Hardee': 'Micropolitan',
#  'Hendry': 'Micropolitan',
#  'Hernando': 'Large Fringe Metro',
#  'Highlands': 'Small Metro',
#  'Hillsborough': 'Medium Metro',
#  'Holmes': 'Non-Core',
#  'Indian River': 'Small Metro',
#  'Leon': 'Non-Core',
#  'Levy': 'Non-Core',
#  'Liberty': 'Large Fringe Metro',
#  'Manatee': 'Medium Metro',
#  'Martin': 'Small Metro',
#  'Miami-Dade': 'Large Central Metro',
#  'Nassau': 'Large Fringe Metro',
#  'Okaloosa': 'Small Metro',
#  'Okeechobee': 'Micropolitan',
#  'Osceola': 'Non-Core',
#  'Palm Beach': 'Large Fringe Metro',
#  'Pasco': 'Large Fringe Metro',
#  'Pinellas': 'Large Central Metro',
#  'Putnam': 'Medium Metro',
#  'St. Johns': 'Large Fringe Metro',
#  'St. Lucie': 'Medium Metro',
#  'Santa Rosa': 'Medium Metro',
#  'Sarasota': 'Medium Metro',
#  'Seminole': 'Non-Core',
#  'Suwannee': 'Non-Core',
#  'Taylor': 'Non-Core',
#  'Volusia': 'Medium Metro',
#  'Wakulla': 'Medium Metro',
#  'Walton': 'Large Fringe Metro',
#  'Appling': 'Non-Core',
#  'Atkinson': 'Non-Core',
#  'Bacon': 'Non-Core',
#  'Banks': 'Non-Core',
#  'Barrow': 'Large Fringe Metro',
#  'Bartow': 'Large Fringe Metro',
#  'Ben Hill': 'Micropolitan',
#  'Berrien': 'Small Metro',
#  'Bleckley': 'Non-Core',
#  'Brantley': 'Small Metro',
#  'Brooks': 'Non-Core',
#  'Bryan': 'Micropolitan',
#  'Bulloch': 'Micropolitan',
#  'Burke': 'Non-Core',
#  'Butts': 'Large Fringe Metro',
#  'Camden': 'Micropolitan',
#  'Candler': 'Non-Core',
#  'Catoosa': 'Medium Metro',
#  'Charlton': 'Non-Core',
#  'Chatham': 'Medium Metro',
#  'Chattahoochee': 'Medium Metro',
#  'Chattooga': 'Micropolitan',
#  'Clayton': 'Non-Core',
#  'Clinch': 'Non-Core',
#  'Cobb': 'Large Fringe Metro',
#  'Colquitt': 'Micropolitan',
#  'Cook': 'Non-Core',
#  'Coweta': 'Large Fringe Metro',
#  'Crisp': 'Micropolitan',
#  'Dade': 'Non-Core',
#  'Dawson': 'Micropolitan',
#  'Decatur': 'Non-Core',
#  'Dodge': 'Micropolitan',
#  'Dooly': 'Non-Core',
#  'Dougherty': 'Small Metro',
#  'Early': 'Non-Core',
#  'Echols': 'Small Metro',
#  'Effingham': 'Micropolitan',
#  'Emanuel': 'Non-Core',
#  'Evans': 'Non-Core',
#  'Fannin': 'Non-Core',
#  'Floyd': 'Small Metro',
#  'Forsyth': 'Medium Metro',
#  'Gilmer': 'Non-Core',
#  'Glascock': 'Non-Core',
#  'Glynn': 'Small Metro',
#  'Gordon': 'Micropolitan',
#  'Grady': 'Large Fringe Metro',
#  'Gwinnett': 'Large Fringe Metro',
#  'Habersham': 'Micropolitan',
#  'Hall': 'Non-Core',
#  'Hancock': 'Small Metro',
#  'Haralson': 'Large Fringe Metro',
#  'Harris': 'Large Central Metro',
#  'Hart': 'Non-Core',
#  'Heard': 'Large Fringe Metro',
#  'Irwin': 'Non-Core',
#  'Jasper': 'Non-Core',
#  'Jeff Davis': 'Non-Core',
#  'Jenkins': 'Non-Core',
#  'Jones': 'Small Metro',
#  'Lanier': 'Small Metro',
#  'Laurens': 'Medium Metro',
#  'Long': 'Small Metro',
#  'Lumpkin': 'Non-Core',
#  'McDuffie': 'Medium Metro',
#  'McIntosh': 'Non-Core',
#  'Meriwether': 'Large Fringe Metro',
#  'Mitchell': 'Non-Core',
#  'Murray': 'Non-Core',
#  'Muscogee': 'Medium Metro',
#  'Oconee': 'Micropolitan',
#  'Oglethorpe': 'Small Metro',
#  'Paulding': 'Non-Core',
#  'Peach': 'Small Metro',
#  'Pierce': 'Large Fringe Metro',
#  'Quitman': 'Non-Core',
#  'Rabun': 'Non-Core',
#  'Richmond': 'Non-Core',
#  'Rockdale': 'Large Fringe Metro',
#  'Schley': 'Micropolitan',
#  'Screven': 'Non-Core',
#  'Spalding': 'Large Fringe Metro',
#  'Stephens': 'Non-Core',
#  'Stewart': 'Non-Core',
#  'Talbot': 'Micropolitan',
#  'Taliaferro': 'Non-Core',
#  'Tattnall': 'Non-Core',
#  'Telfair': 'Non-Core',
#  'Terrell': 'Non-Core',
#  'Thomas': 'Non-Core',
#  'Tift': 'Micropolitan',
#  'Toombs': 'Micropolitan',
#  'Towns': 'Non-Core',
#  'Treutlen': 'Non-Core',
#  'Troup': 'Micropolitan',
#  'Turner': 'Small Metro',
#  'Twiggs': 'Small Metro',
#  'Upson': 'Micropolitan',
#  'Ware': 'Micropolitan',
#  'Warren': 'Large Fringe Metro',
#  'Wayne': 'Medium Metro',
#  'Webster': 'Non-Core',
#  'Wheeler': 'Non-Core',
#  'Whitfield': 'Small Metro',
#  'Wilkes': 'Micropolitan',
#  'Wilkinson': 'Non-Core',
#  'Worth': 'Non-Core',
#  'Hawaii': 'Micropolitan',
#  'Honolulu': 'Medium Metro',
#  'Kalawao': 'Small Metro',
#  'Kauai': 'Micropolitan',
#  'Maui': 'Small Metro',
#  'Ada': 'Medium Metro',
#  'Bannock': 'Small Metro',
#  'Bear Lake': 'Non-Core',
#  'Benewah': 'Non-Core',
#  'Bingham': 'Micropolitan',
#  'Blaine': 'Non-Core',
#  'Boise': 'Medium Metro',
#  'Bonner': 'Micropolitan',
#  'Bonneville': 'Small Metro',
#  'Boundary': 'Non-Core',
#  'Camas': 'Micropolitan',
#  'Canyon': 'Medium Metro',
#  'Caribou': 'Non-Core',
#  'Cassia': 'Micropolitan',
#  'Clearwater': 'Non-Core',
#  'Gem': 'Medium Metro',
#  'Gooding': 'Non-Core',
#  'Idaho': 'Non-Core',
#  'Jerome': 'Micropolitan',
#  'Kootenai': 'Small Metro',
#  'Latah': 'Micropolitan',
#  'Lemhi': 'Non-Core',
#  'Lewis': 'Non-Core',
#  'Minidoka': 'Micropolitan',
#  'Nez Perce': 'Small Metro',
#  'Oneida': 'Non-Core',
#  'Owyhee': 'Medium Metro',
#  'Payette': 'Micropolitan',
#  'Power': 'Non-Core',
#  'Shoshone': 'Non-Core',
#  'Teton': 'Micropolitan',
#  'Twin Falls': 'Micropolitan',
#  'Valley': 'Non-Core',
#  'Alexander': 'Medium Metro',
#  'Bond': 'Large Fringe Metro',
#  'Brown': 'Medium Metro',
#  'Bureau': 'Micropolitan',
#  'Cass': 'Non-Core',
#  'Champaign': 'Micropolitan',
#  'Christian': 'Medium Metro',
#  'Clinton': 'Micropolitan',
#  'Coles': 'Micropolitan',
#  'Cumberland': 'Non-Core',
#  'De Witt': 'Small Metro',
#  'DuPage': 'Large Fringe Metro',
#  'Edgar': 'Non-Core',
#  'Edwards': 'Non-Core',
#  'Ford': 'Micropolitan',
#  'Gallatin': 'Micropolitan',
#  'Grundy': 'Non-Core',
#  'Hardin': 'Medium Metro',
#  'Henderson': 'Micropolitan',
#  'Iroquois': 'Non-Core',
#  'Jersey': 'Large Fringe Metro',
#  'Jo Daviess': 'Non-Core',
#  'Kane': 'Non-Core',
#  'Kankakee': 'Small Metro',
#  'Kendall': 'Large Fringe Metro',
#  'Knox': 'Non-Core',
#  'La Salle': 'Non-Core',
#  'Livingston': 'Large Fringe Metro',
#  'McDonough': 'Micropolitan',
#  'McHenry': 'Micropolitan',
#  'McLean': 'Non-Core',
#  'Macoupin': 'Large Fringe Metro',
#  'Mason': 'Micropolitan',
#  'Massac': 'Micropolitan',
#  'Menard': 'Non-Core',
#  'Mercer': 'Micropolitan',
#  'Moultrie': 'Non-Core',
#  'Ogle': 'Micropolitan',
#  'Peoria': 'Medium Metro',
#  'Piatt': 'Small Metro',
#  'Richland': 'Non-Core',
#  'Rock Island': 'Medium Metro',
#  'Sangamon': 'Small Metro',
#  'Schuyler': 'Non-Core',
#  'Stark': 'Medium Metro',
#  'Stephenson': 'Micropolitan',
#  'Tazewell': 'Micropolitan',
#  'Vermilion': 'Small Metro',
#  'Wabash': 'Micropolitan',
#  'Whiteside': 'Micropolitan',
#  'Will': 'Large Fringe Metro',
#  'Williamson': 'Large Fringe Metro',
#  'Winnebago': 'Small Metro',
#  'Woodford': 'Medium Metro',
#  'Allen': 'Small Metro',
#  'Bartholomew': 'Small Metro',
#  'Blackford': 'Non-Core',
#  'Daviess': 'Non-Core',
#  'Dearborn': 'Large Fringe Metro',
#  'Delaware': 'Large Fringe Metro',
#  'Dubois': 'Micropolitan',
#  'Elkhart': 'Small Metro',
#  'Fountain': 'Non-Core',
#  'Gibson': 'Non-Core',
#  'Harrison': 'Micropolitan',
#  'Hendricks': 'Large Fringe Metro',
#  'Huntington': 'Micropolitan',
#  'Jay': 'Non-Core',
#  'Jennings': 'Micropolitan',
#  'Kosciusko': 'Micropolitan',
#  'LaGrange': 'Non-Core',
#  'LaPorte': 'Small Metro',
#  'Miami': 'Medium Metro',
#  'Noble': 'Non-Core',
#  'Ohio': 'Small Metro',
#  'Owen': 'Non-Core',
#  'Parke': 'Non-Core',
#  'Porter': 'Large Fringe Metro',
#  'Posey': 'Medium Metro',
#  'Ripley': 'Non-Core',
#  'Rush': 'Non-Core',
#  'St. Joseph': 'Micropolitan',
#  'Spencer': 'Large Fringe Metro',
#  'Starke': 'Non-Core',
#  'Steuben': 'Micropolitan',
#  'Sullivan': 'Medium Metro',
#  'Switzerland': 'Non-Core',
#  'Tippecanoe': 'Small Metro',
#  'Tipton': 'Large Fringe Metro',
#  'Vanderburgh': 'Medium Metro',
#  'Vermillion': 'Small Metro',
#  'Vigo': 'Small Metro',
#  'Warrick': 'Medium Metro',
#  'Wells': 'Non-Core',
#  'Whitley': 'Micropolitan',
#  'Adair': 'Non-Core',
#  'Allamakee': 'Non-Core',
#  'Appanoose': 'Non-Core',
#  'Audubon': 'Non-Core',
#  'Black Hawk': 'Small Metro',
#  'Bremer': 'Small Metro',
#  'Buchanan': 'Non-Core',
#  'Buena Vista': 'Micropolitan',
#  'Cedar': 'Non-Core',
#  'Cerro Gordo': 'Micropolitan',
#  'Chickasaw': 'Non-Core',
#  'Davis': 'Medium Metro',
#  'Des Moines': 'Micropolitan',
#  'Dickinson': 'Micropolitan',
#  'Dubuque': 'Small Metro',
#  'Emmet': 'Non-Core',
#  'Guthrie': 'Medium Metro',
#  'Ida': 'Non-Core',
#  'Iowa': 'Medium Metro',
#  'Keokuk': 'Non-Core',
#  'Kossuth': 'Non-Core',
#  'Linn': 'Small Metro',
#  'Louisa': 'Non-Core',
#  'Lucas': 'Medium Metro',
#  'Lyon': 'Micropolitan',
#  'Mahaska': 'Micropolitan',
#  'Mills': 'Non-Core',
#  'Monona': 'Non-Core',
#  'Muscatine': 'Micropolitan',
#  "O'Brien": 'Non-Core',
#  'Page': 'Non-Core',
#  'Palo Alto': 'Non-Core',
#  'Plymouth': 'Large Fringe Metro',
#  'Pocahontas': 'Non-Core',
#  'Pottawattamie': 'Medium Metro',
#  'Poweshiek': 'Non-Core',
#  'Ringgold': 'Non-Core',
#  'Sac': 'Non-Core',
#  'Sioux': 'Small Metro',
#  'Story': 'Small Metro',
#  'Tama': 'Non-Core',
#  'Wapello': 'Micropolitan',
#  'Winneshiek': 'Non-Core',
#  'Woodbury': 'Small Metro',
#  'Wright': 'Non-Core',
#  'Anderson': 'Micropolitan',
#  'Atchison': 'Non-Core',
#  'Barber': 'Non-Core',
#  'Barton': 'Non-Core',
#  'Bourbon': 'Medium Metro',
#  'Chase': 'Non-Core',
#  'Chautauqua': 'Micropolitan',
#  'Cloud': 'Non-Core',
#  'Coffey': 'Non-Core',
#  'Comanche': 'Non-Core',
#  'Cowley': 'Micropolitan',
#  'Doniphan': 'Small Metro',
#  'Elk': 'Non-Core',
#  'Ellis': 'Large Fringe Metro',
#  'Ellsworth': 'Non-Core',
#  'Finney': 'Micropolitan',
#  'Geary': 'Micropolitan',
#  'Gove': 'Non-Core',
#  'Gray': 'Micropolitan',
#  'Greeley': 'Non-Core',
#  'Greenwood': 'Micropolitan',
#  'Harper': 'Non-Core',
#  'Harvey': 'Medium Metro',
#  'Haskell': 'Non-Core',
#  'Hodgeman': 'Non-Core',
#  'Jewell': 'Non-Core',
#  'Kearny': 'Micropolitan',
#  'Kingman': 'Medium Metro',
#  'Labette': 'Micropolitan',
#  'Lane': 'Medium Metro',
#  'Leavenworth': 'Large Fringe Metro',
#  'McPherson': 'Non-Core',
#  'Meade': 'Small Metro',
#  'Morris': 'Non-Core',
#  'Morton': 'Small Metro',
#  'Nemaha': 'Non-Core',
#  'Neosho': 'Non-Core',
#  'Ness': 'Non-Core',
#  'Norton': 'Non-Core',
#  'Osage': 'Medium Metro',
#  'Osborne': 'Non-Core',
#  'Ottawa': 'Micropolitan',
#  'Pawnee': 'Medium Metro',
#  'Pottawatomie': 'Micropolitan',
#  'Pratt': 'Non-Core',
#  'Rawlins': 'Non-Core',
#  'Reno': 'Micropolitan',
#  'Republic': 'Non-Core',
#  'Rice': 'Micropolitan',
#  'Riley': 'Small Metro',
#  'Rooks': 'Non-Core',
#  'Seward': 'Medium Metro',
#  'Shawnee': 'Small Metro',
#  'Sheridan': 'Micropolitan',
#  'Sherman': 'Non-Core',
#  'Smith': 'Small Metro',
#  'Stafford': 'Large Fringe Metro',
#  'Stanton': 'Micropolitan',
#  'Stevens': 'Medium Metro',
#  'Sumner': 'Large Fringe Metro',
#  'Trego': 'Non-Core',
#  'Wabaunsee': 'Small Metro',
#  'Wallace': 'Non-Core',
#  'Wichita': 'Small Metro',
#  'Wilson': 'Large Fringe Metro',
#  'Woodson': 'Non-Core',
#  'Wyandotte': 'Large Fringe Metro',
#  'Ballard': 'Micropolitan',
#  'Barren': 'Micropolitan',
#  'Bath': 'Non-Core',
#  'Bell': 'Medium Metro',
#  'Boyd': 'Non-Core',
#  'Boyle': 'Micropolitan',
#  'Bracken': 'Large Fringe Metro',
#  'Breathitt': 'Non-Core',
#  'Breckinridge': 'Non-Core',
#  'Bullitt': 'Large Fringe Metro',
#  'Caldwell': 'Large Fringe Metro',
#  'Calloway': 'Micropolitan',
#  'Campbell': 'Micropolitan',
#  'Carlisle': 'Non-Core',
#  'Carter': 'Small Metro',
#  'Casey': 'Non-Core',
#  'Edmonson': 'Small Metro',
#  'Elliott': 'Non-Core',
#  'Estill': 'Non-Core',
#  'Fleming': 'Non-Core',
#  'Garrard': 'Non-Core',
#  'Graves': 'Micropolitan',
#  'Grayson': 'Non-Core',
#  'Green': 'Medium Metro',
#  'Greenup': 'Medium Metro',
#  'Harlan': 'Non-Core',
#  'Hickman': 'Large Fringe Metro',
#  'Hopkins': 'Micropolitan',
#  'Jessamine': 'Medium Metro',
#  'Kenton': 'Large Fringe Metro',
#  'Knott': 'Non-Core',
#  'Larue': 'Small Metro',
#  'Laurel': 'Micropolitan',
#  'Leslie': 'Non-Core',
#  'Letcher': 'Non-Core',
#  'McCracken': 'Micropolitan',
#  'McCreary': 'Non-Core',
#  'Magoffin': 'Non-Core',
#  'Menifee': 'Micropolitan',
#  'Metcalfe': 'Micropolitan',
#  'Muhlenberg': 'Non-Core',
#  'Nelson': 'Small Metro',
#  'Nicholas': 'Non-Core',
#  'Oldham': 'Medium Metro',
#  'Owsley': 'Non-Core',
#  'Pendleton': 'Non-Core',
#  'Powell': 'Non-Core',
#  'Robertson': 'Small Metro',
#  'Rockcastle': 'Micropolitan',
#  'Rowan': 'Large Fringe Metro',
#  'Simpson': 'Medium Metro',
#  'Todd': 'Non-Core',
#  'Trigg': 'Medium Metro',
#  'Trimble': 'Large Fringe Metro',
#  'Wolfe': 'Non-Core',
#  'Acadia Parish': 'Medium Metro',
#  'Allen Parish': 'Non-Core',
#  'Ascension Parish': 'Medium Metro',
#  'Assumption Parish': 'Non-Core',
#  'Avoyelles Parish': 'Non-Core',
#  'Beauregard Parish': 'Micropolitan',
#  'Bienville Parish': 'Non-Core',
#  'Bossier Parish': 'Medium Metro',
#  'Caddo Parish': 'Medium Metro',
#  'Calcasieu Parish': 'Small Metro',
#  'Caldwell Parish': 'Non-Core',
#  'Cameron Parish': 'Small Metro',
#  'Catahoula Parish': 'Non-Core',
#  'Claiborne Parish': 'Non-Core',
#  'Concordia Parish': 'Micropolitan',
#  'De Soto Parish': 'Medium Metro',
#  'East Baton Rouge Parish': 'Medium Metro',
#  'East Carroll Parish': 'Non-Core',
#  'East Feliciana Parish': 'Medium Metro',
#  'Evangeline Parish': 'Non-Core',
#  'Franklin Parish': 'Non-Core',
#  'Grant Parish': 'Small Metro',
#  'Iberia Parish': 'Medium Metro',
#  'Iberville Parish': 'Medium Metro',
#  'Jackson Parish': 'Non-Core',
#  'Jefferson Parish': 'Large Fringe Metro',
#  'Jefferson Davis Parish': 'Non-Core',
#  'Lafayette Parish': 'Medium Metro',
#  'Lafourche Parish': 'Small Metro',
#  'LaSalle Parish': 'Non-Core',
#  'Lincoln Parish': 'Micropolitan',
#  'Livingston Parish': 'Medium Metro',
#  'Madison Parish': 'Non-Core',
#  'Morehouse Parish': 'Micropolitan',
#  'Natchitoches Parish': 'Micropolitan',
#  'Orleans Parish': 'Large Central Metro',
#  'Ouachita Parish': 'Small Metro',
#  'Plaquemines Parish': 'Large Fringe Metro',
#  'Pointe Coupee Parish': 'Medium Metro',
#  'Rapides Parish': 'Small Metro',
#  'Red River Parish': 'Non-Core',
#  'Richland Parish': 'Non-Core',
#  'Sabine Parish': 'Non-Core',
#  'St. Bernard Parish': 'Large Fringe Metro',
#  'St. Charles Parish': 'Large Fringe Metro',
#  'St. Helena Parish': 'Medium Metro',
#  'St. James Parish': 'Large Fringe Metro',
#  'St. John the Baptist Parish': 'Large Fringe Metro',
#  'St. Landry Parish': 'Micropolitan',
#  'St. Martin Parish': 'Medium Metro',
#  'St. Mary Parish': 'Micropolitan',
#  'St. Tammany Parish': 'Large Fringe Metro',
#  'Tangipahoa Parish': 'Small Metro',
#  'Tensas Parish': 'Non-Core',
#  'Terrebonne Parish': 'Small Metro',
#  'Union Parish': 'Small Metro',
#  'Vermilion Parish': 'Medium Metro',
#  'Vernon Parish': 'Micropolitan',
#  'Washington Parish': 'Micropolitan',
#  'Webster Parish': 'Medium Metro',
#  'West Baton Rouge Parish': 'Medium Metro',
#  'West Carroll Parish': 'Non-Core',
#  'West Feliciana Parish': 'Medium Metro',
#  'Winn Parish': 'Non-Core',
#  'Androscoggin': 'Small Metro',
#  'Aroostook': 'Non-Core',
#  'Kennebec': 'Micropolitan',
#  'Oxford': 'Non-Core',
#  'Penobscot': 'Small Metro',
#  'Piscataquis': 'Non-Core',
#  'Sagadahoc': 'Medium Metro',
#  'Somerset': 'Micropolitan',
#  'Waldo': 'Non-Core',
#  'York': 'Large Fringe Metro',
#  'Allegany': 'Non-Core',
#  'Anne Arundel': 'Large Fringe Metro',
#  'Baltimore': 'Large Fringe Metro',
#  'Calvert': 'Large Fringe Metro',
#  'Caroline': 'Large Fringe Metro',
#  'Cecil': 'Large Fringe Metro',
#  'Charles': 'Large Fringe Metro',
#  'Dorchester': 'Medium Metro',
#  'Frederick': 'Small Metro',
#  'Garrett': 'Non-Core',
#  'Harford': 'Large Fringe Metro',
#  "Prince George's": 'Large Fringe Metro',
#  "Queen Anne's": 'Large Fringe Metro',
#  "St. Mary's": 'Small Metro',
#  'Wicomico': 'Medium Metro',
#  'Worcester': 'Medium Metro',
#  'Baltimore city': 'Large Central Metro',
#  'Barnstable': 'Small Metro',
#  'Berkshire': 'Small Metro',
#  'Bristol': 'Large Fringe Metro',
#  'Dukes': 'Micropolitan',
#  'Essex': 'Non-Core',
#  'Hampden': 'Medium Metro',
#  'Hampshire': 'Small Metro',
#  'Nantucket': 'Non-Core',
#  'Norfolk': 'Large Fringe Metro',
#  'Suffolk': 'Large Fringe Metro',
#  'Alcona': 'Non-Core',
#  'Alger': 'Non-Core',
#  'Allegan': 'Micropolitan',
#  'Alpena': 'Micropolitan',
#  'Antrim': 'Non-Core',
#  'Arenac': 'Non-Core',
#  'Baraga': 'Non-Core',
#  'Barry': 'Non-Core',
#  'Benzie': 'Micropolitan',
#  'Branch': 'Micropolitan',
#  'Charlevoix': 'Non-Core',
#  'Cheboygan': 'Non-Core',
#  'Chippewa': 'Small Metro',
#  'Clare': 'Non-Core',
#  'Eaton': 'Medium Metro',
#  'Genesee': 'Micropolitan',
#  'Gladwin': 'Non-Core',
#  'Gogebic': 'Non-Core',
#  'Grand Traverse': 'Micropolitan',
#  'Gratiot': 'Micropolitan',
#  'Hillsdale': 'Micropolitan',
#  'Houghton': 'Micropolitan',
#  'Huron': 'Micropolitan',
#  'Ingham': 'Medium Metro',
#  'Ionia': 'Micropolitan',
#  'Iosco': 'Non-Core',
#  'Iron': 'Non-Core',
#  'Isabella': 'Micropolitan',
#  'Kalamazoo': 'Medium Metro',
#  'Kalkaska': 'Micropolitan',
#  'Keweenaw': 'Micropolitan',
#  'Lapeer': 'Large Fringe Metro',
#  'Leelanau': 'Micropolitan',
#  'Lenawee': 'Micropolitan',
#  'Luce': 'Non-Core',
#  'Mackinac': 'Non-Core',
#  'Macomb': 'Large Fringe Metro',
#  'Manistee': 'Non-Core',
#  'Marquette': 'Non-Core',
#  'Mecosta': 'Micropolitan',
#  'Menominee': 'Micropolitan',
#  'Midland': 'Small Metro',
#  'Missaukee': 'Micropolitan',
#  'Montcalm': 'Large Fringe Metro',
#  'Montmorency': 'Non-Core',
#  'Muskegon': 'Small Metro',
#  'Newaygo': 'Non-Core',
#  'Oakland': 'Large Fringe Metro',
#  'Oceana': 'Non-Core',
#  'Ogemaw': 'Non-Core',
#  'Ontonagon': 'Non-Core',
#  'Oscoda': 'Non-Core',
#  'Otsego': 'Micropolitan',
#  'Presque Isle': 'Non-Core',
#  'Roscommon': 'Non-Core',
#  'Saginaw': 'Small Metro',
#  'Sanilac': 'Non-Core',
#  'Schoolcraft': 'Non-Core',
#  'Shiawassee': 'Micropolitan',
#  'Tuscola': 'Non-Core',
#  'Washtenaw': 'Medium Metro',
#  'Wexford': 'Micropolitan',
#  'Aitkin': 'Non-Core',
#  'Anoka': 'Large Fringe Metro',
#  'Becker': 'Non-Core',
#  'Beltrami': 'Micropolitan',
#  'Big Stone': 'Non-Core',
#  'Blue Earth': 'Small Metro',
#  'Carlton': 'Medium Metro',
#  'Carver': 'Large Fringe Metro',
#  'Chisago': 'Large Fringe Metro',
#  'Cottonwood': 'Non-Core',
#  'Crow Wing': 'Micropolitan',
#  'Dakota': 'Small Metro',
#  'Faribault': 'Non-Core',
#  'Fillmore': 'Non-Core',
#  'Freeborn': 'Micropolitan',
#  'Goodhue': 'Micropolitan',
#  'Hennepin': 'Large Central Metro',
#  'Hubbard': 'Non-Core',
#  'Isanti': 'Large Fringe Metro',
#  'Itasca': 'Non-Core',
#  'Kanabec': 'Non-Core',
#  'Kandiyohi': 'Micropolitan',
#  'Kittson': 'Non-Core',
#  'Koochiching': 'Non-Core',
#  'Lac qui Parle': 'Non-Core',
#  'Lake of the Woods': 'Non-Core',
#  'Le Sueur': 'Large Fringe Metro',
#  'McLeod': 'Micropolitan',
#  'Mahnomen': 'Non-Core',
#  'Meeker': 'Non-Core',
#  'Mille Lacs': 'Large Fringe Metro',
#  'Morrison': 'Non-Core',
#  'Mower': 'Micropolitan',
#  'Nicollet': 'Small Metro',
#  'Nobles': 'Micropolitan',
#  'Norman': 'Non-Core',
#  'Olmsted': 'Small Metro',
#  'Otter Tail': 'Micropolitan',
#  'Pennington': 'Small Metro',
#  'Pine': 'Non-Core',
#  'Pipestone': 'Non-Core',
#  'Ramsey': 'Non-Core',
#  'Red Lake': 'Non-Core',
#  'Redwood': 'Non-Core',
#  'Renville': 'Micropolitan',
#  'Rock': 'Small Metro',
#  'Roseau': 'Non-Core',
#  'St. Louis': 'Large Fringe Metro',
#  'Sherburne': 'Large Fringe Metro',
#  'Sibley': 'Large Fringe Metro',
#  'Stearns': 'Small Metro',
#  'Steele': 'Non-Core',
#  'Swift': 'Non-Core',
#  'Traverse': 'Non-Core',
#  'Wabasha': 'Small Metro',
#  'Wadena': 'Non-Core',
#  'Waseca': 'Non-Core',
#  'Watonwan': 'Non-Core',
#  'Wilkin': 'Micropolitan',
#  'Winona': 'Micropolitan',
#  'Yellow Medicine': 'Non-Core',
#  'Alcorn': 'Micropolitan',
#  'Amite': 'Micropolitan',
#  'Attala': 'Non-Core',
#  'Bolivar': 'Micropolitan',
#  'Claiborne': 'Non-Core',
#  'Coahoma': 'Micropolitan',
#  'Copiah': 'Medium Metro',
#  'Forrest': 'Small Metro',
#  'George': 'Non-Core',
#  'Grenada': 'Micropolitan',
#  'Hinds': 'Medium Metro',
#  'Humphreys': 'Non-Core',
#  'Issaquena': 'Non-Core',
#  'Itawamba': 'Micropolitan',
#  'Jefferson Davis': 'Non-Core',
#  'Kemper': 'Micropolitan',
#  'Leake': 'Non-Core',
#  'Leflore': 'Micropolitan',
#  'Neshoba': 'Non-Core',
#  'Noxubee': 'Non-Core',
#  'Oktibbeha': 'Micropolitan',
#  'Panola': 'Non-Core',
#  'Pearl River': 'Micropolitan',
#  'Pontotoc': 'Micropolitan',
#  ...}

# %% [markdown]
# ##### Importação do dataset sobre limites de velocidade

# %%
def discretize_speed(x):
    if x < 70:
        return 'Low'
    elif 70 <= x < 80:
        return 'Medium'
    else:
        return 'High'

# import maximum speed limits by state
speed_limits = pd.read_excel('speed_limit_state.xlsx')

# drop unwanted information
speed_limits = speed_limits.drop(['Freeway (trucks)','Freeway (urban)','Divided (rural)','Undivided (rural)','Residential'], axis=1)

speed_limits = speed_limits.rename(columns={'State or territory': 'State', 'Freeway (rural)': 'Max Speed Limit (mph)'})

# List of all the US States
us_states = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
             'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois',
             'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
             'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
             'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
             'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
             'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas','Utah',
             'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']

# cleaning, avoid applying the function to missing values
speed_limits['State'] = speed_limits['State'].map(lambda x: re.sub('[^a-z A-Z]+', '', x), na_action='ignore')
speed_limits['Max Speed Limit (mph)'] = speed_limits['Max Speed Limit (mph)'].map(lambda x: re.sub('\(.*', '', x), na_action='ignore')

# filter out non US States
speed_limits = speed_limits[speed_limits['State'].isin(us_states)]

# more cleaning
speed_limits['Max Speed Limit (mph)'] = speed_limits['Max Speed Limit (mph)'].map(lambda x: int(x[:-4][-3:]))
speed_limits.at[41, 'Max Speed Limit (mph)'] = 70

# sort and reset index
speed_limits = speed_limits.sort_values(by=['Max Speed Limit (mph)'], ascending=False).reset_index(drop=True)

speed_limits['Discrete Max Speed Limit'] = speed_limits['Max Speed Limit (mph)'].map(discretize_speed)

speed_dict = pd.Series(speed_limits['Discrete Max Speed Limit'].values, index=speed_limits['State']).to_dict()
speed_dict
# Out:
# {'Texas': 'High',
#  'Montana': 'High',
#  'Idaho': 'High',
#  'Utah': 'High',
#  'South Dakota': 'High',
#  'Nevada': 'High',
#  'Wyoming': 'High',
#  'Maine': 'Medium',
#  'Michigan': 'Medium',
#  'North Dakota': 'Medium',
#  'Colorado': 'Medium',
#  'Nebraska': 'Medium',
#  'Arizona': 'Medium',
#  'Arkansas': 'Medium',
#  'Kansas': 'Medium',
#  'Oklahoma': 'Medium',
#  'Louisiana': 'Medium',
#  'New Mexico': 'Medium',
#  'Ohio': 'Medium',
#  'Oregon': 'Medium',
#  'Pennsylvania': 'Medium',
#  'New Hampshire': 'Medium',
#  'South Carolina': 'Medium',
#  'California': 'Medium',
#  'Tennessee': 'Medium',
#  'Virginia': 'Medium',
#  'Washington': 'Medium',
#  'West Virginia': 'Medium',
#  'Wisconsin': 'Medium',
#  'North Carolina': 'Medium',
#  'Alabama': 'Medium',
#  'Maryland': 'Medium',
#  'Indiana': 'Medium',
#  'Florida': 'Medium',
#  'Georgia': 'Medium',
#  'Missouri': 'Medium',
#  'Mississippi': 'Medium',
#  'Minnesota': 'Medium',
#  'Illinois': 'Medium',
#  'Kentucky': 'Medium',
#  'Iowa': 'Medium',
#  'Connecticut': 'Low',
#  'Vermont': 'Low',
#  'New York': 'Low',
#  'New Jersey': 'Low',
#  'Massachusetts': 'Low',
#  'Rhode Island': 'Low',
#  'Alaska': 'Low',
#  'Delaware': 'Low',
#  'Hawaii': 'Low'}

# %% [markdown]
# ### Tratamento do dataset original
#
# #### Tratamento de dados nulos/incompletos
#
# * As linhas que têm valores relativos ao twilight e período do dia vazios serão removidas;
# * As linhas que não têm informação relativa à cidade na qual o acidente ocorre também serão removidas;
# * Os códigos TMC (Traffic Message Channel) que sejam nulos serão identificados com um número fora do domínio dos códigos existentes e não vão ser relevantes para possíveis interrogações;
# * Definição de valores para dados meteorológicos nulos será feita com base na média de valores em cada atributo, ao nível da cidade,
# na respetiva semana em que ocorreu o acidente (tal será feito na criação da *dimension* Weather);
# * O preenchimento de dados quem não contêm fuso horário será feito através da correspondência entre o estado onde o acidente ocorreu e o fuso horário no qual se encontra.
#
# #### Remoção de colunas
# * 'Source',
# * 'Start_Lat',
# * 'Country',
# * 'Start_Lng',
# * 'End_Lat',
# * 'End_Lng',
# * 'Description',
# * 'Number',
# * 'Side',
# * 'Zipcode',
# * 'Airport_Code',
# * 'Weather_Timestamp',
# * 'Pressure(in)',
# * 'Wind_Chill(F)'

# %%
us_acidents.columns
# Out:
# Index(['ID', 'Source', 'TMC', 'Severity', 'Start_Time', 'End_Time',
#        'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)',
#        'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
#        'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
#        'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
# drop unuseful information/columns
us_acidents = us_acidents.drop(['Source', 'Start_Lat', 'Country', 'Start_Lng', 'End_Lat', 'End_Lng', 'Description', 'Number', 'Side', 'Zipcode', 'Airport_Code', 'Weather_Timestamp', 'Pressure(in)', 'Wind_Chill(F)'], axis=1)

# %%
# delete rows with non avaliable values
us_acidents = us_acidents.dropna(subset=['City', 'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight']).reset_index(drop=True)

# %%
# replace TMC values with out-of-range values, not used in OLAP.
us_acidents['TMC'].fillna(-1, inplace=True)

# %%
# replace empty timezone values with the correspondent ones from each state
timezone_df = us_acidents[['State', 'Timezone']].drop_duplicates(subset="State")
timezone_dict = pd.Series(timezone_df['Timezone'].values, index=timezone_df['State']).to_dict()

us_acidents['Timezone'].fillna(us_acidents['State'].map(timezone_dict), inplace=True)

# %%
us_acidents.isna().sum()
# Out:
# ID                           0
# TMC                          0
# Severity                     0
# Start_Time                   0
# End_Time                     0
# Distance(mi)                 0
# Street                       0
# City                         0
# County                       0
# State                        0
# Timezone                     0
# Temperature(F)             879
# Humidity(%)                931
# Visibility(mi)            1053
# Wind_Direction             693
# Wind_Speed(mph)           7419
# Precipitation(in)        33820
# Weather_Condition         1038
# Amenity                      0
# Bump                         0
# Crossing                     0
# Give_Way                     0
# Junction                     0
# No_Exit                      0
# Railway                      0
# Roundabout                   0
# Station                      0
# Stop                         0
# Traffic_Calming              0
# Traffic_Signal               0
# Turning_Loop                 0
# Sunrise_Sunset               0
# Civil_Twilight               0
# Nautical_Twilight            0
# Astronomical_Twilight        0
# dtype: int64

# %% [markdown]
# #### POI Dimension

# %%
# add POI_Key
us_acidents.insert(us_acidents.columns.get_loc('Amenity'), 'POI_Key', range(1, len(us_acidents) + 1))

# %%
# create POI dataframe
poi_dimension = us_acidents.loc[:,'POI_Key':'Turning_Loop']

poi_dimension.columns
# Out:
# Index(['POI_Key', 'Amenity', 'Bump', 'Crossing', 'Give_Way', 'Junction',
#        'No_Exit', 'Railway', 'Roundabout', 'Station', 'Stop',
#        'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop'],
#       dtype='object')

# %%
poi_dimension.sample(5)
# Out:
#        POI_Key  Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  \
# 7308      7309    False  False     False     False     False    False
# 46896    46897    False  False     False     False     False    False
# 39712    39713    False  False     False     False     False    False
# 36480    36481    False  False      True     False     False    False
# 15622    15623    False  False     False     False     False    False
#
#        Railway  Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# 7308     False       False    False  False            False           False
# 46896    False       False    False  False            False            True
# 39712    False       False    False  False            False           False
# 36480    False       False    False  False            False            True
# 15622    False       False    False  False            False           False
#
#        Turning_Loop
# 7308          False
# 46896         False
# 39712         False
# 36480         False
# 15622         False

# %%
# drop unwanted data from the accidents dataframe
#us_acidents = us_acidents.drop(poi_dimension.columns[1:], axis=1)

# accidents dataframe with POI_Key
us_acidents.columns
# Out:
# Index(['ID', 'TMC', 'Severity', 'Start_Time', 'End_Time', 'Distance(mi)',
#        'Street', 'City', 'County', 'State', 'Timezone', 'Temperature(F)',
#        'Humidity(%)', 'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'POI_Key', 'Amenity', 'Bump',
#        'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout',
#        'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %% [markdown]
# #### Location Dimension

# %% [markdown]
# ##### Inserção de Chave

# %%
# add location key
us_acidents.insert(us_acidents.columns.get_loc('Street'), 'LocationKey', range(1, len(us_acidents) + 1))

# %% [markdown]
# ##### Definição dos atributos de região

# %%
us_acidents['State'].unique()
# Out:
# array(['OH', 'CA', 'FL', 'GA', 'SC', 'NE', 'IA', 'IL', 'MO', 'WI', 'MI',
#        'MA', 'CT', 'NY', 'NJ', 'RI', 'NH', 'VA', 'PA', 'MD', 'DE', 'DC',
#        'TX', 'WA', 'OR', 'IN', 'TN', 'AZ', 'OK', 'NC', 'AL', 'UT', 'MN',
#        'KY', 'LA', 'CO', 'KS', 'NV', 'MS', 'NM', 'AR', 'VT', 'WY', 'WV',
#        'ID', 'ME', 'MT', 'SD', 'ND'], dtype=object)

# %%
# Eliminar??
# Muitos dados que temos não incluem este estado - Não é um estado
us_acidents[us_acidents["State"] != 'DC'].reset_index(drop=True, inplace=True)

# %%
replace_values = {'OH':'Ohio', 'WV':'West Virginia', 'CA': 'California', 'FL': 'Florida', 'GA': 'Georgia', 'SC':'South Carolina', 'NE': 'Nebraska', 'IA': 'Iowa', 'IL': 'Illinois', 'MO': 'Missouri', 'WI': 'Wisconsin',
       'IN': 'Indiana', 'MI': 'Michigan', 'NJ': 'New Jersey', 'NY': 'New York', 'CT': 'Connecticut', 'MA': 'Massachusetts', 'RI': 'Rhode Island', 'NH': 'New Hampshire', 'PA': 'Pennsylvania', 'KY': 'Kentucky', 'MD': 'Maryland',
       'VA': 'Virginia', 'DE': 'Delaware', 'TX':'Texas', 'WA': 'Washington', 'OR': 'Oregon', 'AL': 'Alabama', 'NC': 'North Carolina', 'MN': 'Minnesota', 'OK': 'Oklahoma', 'LA': 'Louisiana',
   'TN': 'Tennessee', 'UT': 'Utah', 'CO': 'Colorado', 'AZ': 'Arizona', 'NV': 'Nevada', 'KS': 'Kansas', 'MS': 'Mississippi', 'NM': 'New Mexico', 'ME': 'Maine', 'AR': 'Arkansas', 'WY': 'Wyoming','VT': 'Vermont', 'ID': 'Idaho', 'ND': 'North Dakota', 'MT': 'Montana', 'SD': 'South Dakota'}

# %%
us_acidents = us_acidents.replace({"State": replace_values})

# %%
# https://en.wikipedia.org/wiki/List_of_regions_of_the_United_States#Census_Bureau-designated_regions_and_divisions
sub_regions = {
    'New England': ['Connecticut', 'Maine', 'Massachusetts', 'New Hampshire', 'Rhode Island', 'Vermont'],
    'Mid Atlantic': ['New Jersey', 'New York','Pennsylvania'],
    'East North Central': ['Illinois', 'Indiana', 'Michigan', 'Ohio', 'Wisconsin'],
    'West North Central': ['Iowa','Kansas','Minnesota','Missouri','Nebraska','North Dakota','South Dakota'],
    'South Atlantic': ['Delaware','Florida','Georgia','Maryland','North Carolina','South Carolina','Virginia','West Virginia'],
    'East South Central': ['Alabama','Kentucky','Mississippi','Tennessee'],
    'West South Central': ['Arkansas','Louisiana','Oklahoma','Texas'],
    'Mountain': ['Arizona','Colorado','Idaho','Montana','Nevada','New Mexico','Utah','Wyoming'],
    'Pacific': ['Alaska','California','Hawaii','Oregon','Washington']
}

regions = {
    'Northeast': ['Connecticut', 'Maine', 'Massachusetts', 'New Hampshire', 'Rhode Island', 'Vermont', 'New Jersey', 'New York','Pennsylvania'],
    'Midwest': ['Illinois', 'Indiana', 'Michigan', 'Ohio', 'Wisconsin', 'Iowa','Kansas','Minnesota','Missouri','Nebraska','North Dakota','South Dakota'],
    'South': ['Delaware','Florida','Georgia','Maryland','North Carolina','South Carolina','Virginia','District of Columbia','West Virginia', 'Alabama','Kentucky','Mississippi','Tennessee', 'Arkansas','Louisiana','Oklahoma','Texas'],
    'West': ['Arizona','Colorado','Idaho','Montana','Nevada','New Mexico','Utah','Wyoming', 'Alaska','California','Hawaii','Oregon','Washington']
}

# create an inverted dictionary map
regions_dict = dict([(v, k) for k, l in regions.items() for v in l])
sub_regions_dict = dict([(v, k) for k, l in sub_regions.items() for v in l])

# %% [markdown]
# ##### Inserção dos atributos Região e Sub-Região

# %%
# add region
us_acidents.insert(us_acidents.columns.get_loc("Timezone"), 'Region', us_acidents['State'].map(regions_dict))
us_acidents['Region'].value_counts()
# Out:
# South        20893
# West         16090
# Midwest       6996
# Northeast     5960
# Name: Region, dtype: int64

# %%
# add subregion
us_acidents.insert(us_acidents.columns.get_loc('Timezone'), 'Subregion', us_acidents['State'].map(sub_regions_dict))
us_acidents['Subregion'].value_counts()
# Out:
# Pacific               13473
# South Atlantic        12250
# West South Central     6654
# East North Central     4752
# Mid Atlantic           4679
# Mountain               2617
# West North Central     2244
# East South Central     1989
# New England            1281
# Name: Subregion, dtype: int64

# %% [markdown]
# ##### Inserção de atributo AlcoholConsumptionRate

# %%
# add alcohol consumption
us_acidents.insert(us_acidents.columns.get_loc('Timezone'), 'AlcoholConsumptionRate', us_acidents['State'].map(alcohol_dict))
us_acidents['AlcoholConsumptionRate'].value_counts()
# Out:
# Medium       36521
# High          9222
# Low           4011
# Very High      185
# Name: AlcoholConsumptionRate, dtype: int64

# %% [markdown]
# #### Inserção do atributo NumberVehicleRegistrations

# %%
# add number of vehicles
us_acidents.insert(us_acidents.columns.get_loc('Timezone'), 'VehicleRegistrations', us_acidents['State'].map(vehicle_dict))
us_acidents['VehicleRegistrations'].value_counts()
# Out:
# Medium       14678
# High         10064
# Low           8637
# Very High     4942
# Name: VehicleRegistrations, dtype: int64

# %% [markdown]
# #### Inserção do atributo UrbanRuralClassification

# %%
# add rate
us_acidents.insert(us_acidents.columns.get_loc('Timezone'), 'UrbanRuralClassification', us_acidents['County'].map(urban_dict))

# ~81000 rows dropped - Errors in County, only with manual correction allowed
us_acidents = us_acidents[us_acidents['UrbanRuralClassification'].notna()]

us_acidents['UrbanRuralClassification'].value_counts()
# Out:
# Large Central Metro    18928
# Non-Core                9372
# Medium Metro            7323
# Large Fringe Metro      7048
# Micropolitan            3084
# Small Metro             2534
# Name: UrbanRuralClassification, dtype: int64

# %% [markdown]
# #### Inserção do atributo MaximumSpeedLimit

# %%
# add max speed limit
us_acidents.insert(us_acidents.columns.get_loc('Timezone'), 'MaximumSpeedLimit', us_acidents['State'].map(speed_dict))

us_acidents['MaximumSpeedLimit'].value_counts()
# Out:
# Medium    38036
# High       5841
# Low        4356
# Name: MaximumSpeedLimit, dtype: int64

# %% [markdown]
# TBD:
# * MoonCalendar

# %%
# create location dataframe
location_dimension = us_acidents.loc[:,'LocationKey':'MaximumSpeedLimit']

location_dimension.columns
# Out:
# Index(['LocationKey', 'Street', 'City', 'County', 'State', 'Region',
#        'Subregion', 'AlcoholConsumptionRate', 'VehicleRegistrations',
#        'UrbanRuralClassification', 'MaximumSpeedLimit'],
#       dtype='object')

# %%
# drop unwanted data from the accidents dataframe
#us_acidents = us_acidents.drop(location_dimension.columns[1:], axis=1)

us_acidents.columns
# Out:
# Index(['ID', 'TMC', 'Severity', 'Start_Time', 'End_Time', 'Distance(mi)',
#        'LocationKey', 'Street', 'City', 'County', 'State', 'Region',
#        'Subregion', 'AlcoholConsumptionRate', 'VehicleRegistrations',
#        'UrbanRuralClassification', 'MaximumSpeedLimit', 'Timezone',
#        'Temperature(F)', 'Humidity(%)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'POI_Key',
#        'Amenity', 'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight',
#        'Nautical_Twilight', 'Astronomical_Twilight'],
#       dtype='object')

# %% [markdown]
# #### Date Dimension

# %% [markdown]
# ##### Conversão dos registos Start_Time e End_Time para Datetime

# %%
# convert to timestamp datatype 
us_acidents['Start_Time'] = pd.to_datetime(us_acidents['Start_Time'])
us_acidents['End_Time'] = pd.to_datetime(us_acidents['End_Time'])

# rename columns
us_acidents = us_acidents.rename(columns={'Start_Time': 'Start_Datetime', 'End_Time': 'End_Datetime'})

# %% [markdown]
# ##### Inserção de Chave

# %%
us_acidents.insert(us_acidents.columns.get_loc('Start_Datetime'), 'DateKey', range(1, len(us_acidents) + 1))

# %% [markdown]
# ##### Inserção dos atributos StartDay, StartMonth e StartYear

# %%
# add starting date
us_acidents.insert(us_acidents.columns.get_loc('Start_Datetime'), 'StartDay', us_acidents['Start_Datetime'].map(lambda x: x.day))
us_acidents.insert(us_acidents.columns.get_loc('Start_Datetime'), 'StartMonth', us_acidents['Start_Datetime'].map(lambda x: x.month_name()))
us_acidents.insert(us_acidents.columns.get_loc('Start_Datetime'), 'StartYear', us_acidents['Start_Datetime'].map(lambda x: x.year))

# %% [markdown]
# ##### Inserção dos atributos EndDay, EndMonth e EndYear

# %%
# add ending date
us_acidents.insert(us_acidents.columns.get_loc('Start_Datetime'), 'EndDay', us_acidents['End_Datetime'].map(lambda x: x.day)) 
us_acidents.insert(us_acidents.columns.get_loc('Start_Datetime'), 'EndMonth', us_acidents['End_Datetime'].map(lambda x: x.month_name())) 
us_acidents.insert(us_acidents.columns.get_loc('Start_Datetime'), 'EndYear', us_acidents['End_Datetime'].map(lambda x: x.year))

# %% [markdown]
# ##### Inserção do atributo DayOfWeek

# %%
# add day of the week
us_acidents.insert(us_acidents.columns.get_loc('Start_Datetime'), 'DayOfWeek', us_acidents['Start_Datetime'].map(lambda x: x.day_name()))
us_acidents['DayOfWeek'].value_counts()
# Out:
# Tuesday      8781
# Friday       8766
# Wednesday    8766
# Thursday     8467
# Monday       8127
# Saturday     2875
# Sunday       2507
# Name: DayOfWeek, dtype: int64

# %% [markdown]
# ##### Inserção do atributo WeekdayWeekend

# %%
week_dict = {
    'Monday': 'Week Day',
    'Tuesday': 'Week Day',
    'Wednesday': 'Week Day',
    'Thursday': 'Week Day',
    'Friday': 'Week Day',
    'Saturday': 'Weekend',
    'Sunday': 'Weekend'
}

# %%
# add week day/weekend
us_acidents.insert(us_acidents.columns.get_loc('Start_Datetime'), 'WeekdayWeekend', us_acidents['DayOfWeek'].map(week_dict))
us_acidents[['Start_Datetime', 'DayOfWeek', 'WeekdayWeekend']].sample(5)
# Out:
#            Start_Datetime  DayOfWeek WeekdayWeekend
# 14189 2019-08-05 20:43:55     Monday       Week Day
# 33460 2017-12-23 13:05:52   Saturday        Weekend
# 32822 2017-12-06 08:23:45  Wednesday       Week Day
# 36042 2017-09-14 17:19:34   Thursday       Week Day
# 43175 2019-11-01 21:29:00     Friday       Week Day

# %% [markdown]
# ##### Inserção dos atributos Quarter (trimester) e WeekNumber

# %%
# add quarter and week number
us_acidents.insert(us_acidents.columns.get_loc('Start_Datetime'), 'Quarter', us_acidents['Start_Datetime'].map(lambda x: x.quarter))
us_acidents.insert(us_acidents.columns.get_loc('Start_Datetime'), 'WeekNumber', us_acidents['Start_Datetime'].map(lambda x: x.weekofyear))
us_acidents[['Start_Datetime','Quarter','WeekNumber']].sample(5)
# Out:
#            Start_Datetime  Quarter  WeekNumber
# 207   2017-01-13 18:19:44        1           2
# 36091 2017-09-15 12:51:11        3          37
# 17473 2019-03-06 08:48:24        1          10
# 41192 2017-05-17 17:24:32        2          20
# 17681 2019-03-13 17:22:20        1          11

# %% [markdown]
# ##### Inserção do atributo Holiday

# %%
federal_holidays = pd.read_csv('us_federal_hol.csv', delimiter=';')
federal_holidays['date'] = pd.to_datetime(federal_holidays['date']).dt.date
federal_holidays.sample(5)
# Out:
#           date                  holiday exceptions
# 30  2018-11-11             Veterans Day
# 12  2017-02-01  New Year's Day observed
# 5   2016-05-09                Labor Day
# 26  2018-05-28             Memorial Day
# 23  2018-01-01           New Year's Day

# %%
holidays_dict = pd.Series(federal_holidays['holiday'].values, index=federal_holidays['date']).to_dict()
holidays_dict
# Out:
# {datetime.date(2016, 1, 1): "New Year's Day",
#  datetime.date(2016, 1, 18): '3tin Luther King Jr. Day',
#  datetime.date(2016, 2, 15): "Presidents' Day",
#  datetime.date(2016, 5, 30): 'Memorial Day',
#  datetime.date(2016, 4, 7): 'Independence Day',
#  datetime.date(2016, 5, 9): 'Labor Day',
#  datetime.date(2016, 10, 10): 'Columbus Day',
#  datetime.date(2016, 11, 11): 'Veterans Day',
#  datetime.date(2016, 11, 24): 'Thanksgiving Day',
#  datetime.date(2016, 12, 25): 'Christmas Day',
#  datetime.date(2016, 12, 26): 'Christmas Day observed',
#  datetime.date(2017, 1, 1): "New Year's Day",
#  datetime.date(2017, 2, 1): "New Year's Day observed",
#  datetime.date(2017, 1, 16): '3tin Luther King Jr. Day',
#  datetime.date(2017, 2, 20): "Presidents' Day",
#  datetime.date(2017, 5, 29): 'Memorial Day',
#  datetime.date(2017, 4, 7): 'Independence Day',
#  datetime.date(2017, 4, 9): 'Labor Day',
#  datetime.date(2017, 9, 10): 'Columbus Day',
#  datetime.date(2017, 10, 11): 'Veterans Day observed',
#  datetime.date(2017, 11, 11): 'Veterans Day',
#  datetime.date(2017, 11, 23): 'Thanksgiving Day',
#  datetime.date(2017, 12, 25): 'Christmas Day',
#  datetime.date(2018, 1, 1): "New Year's Day",
#  datetime.date(2018, 1, 15): '3tin Luther King Jr. Day',
#  datetime.date(2018, 2, 19): "Presidents' Day",
#  datetime.date(2018, 5, 28): 'Memorial Day',
#  datetime.date(2018, 4, 7): 'Independence Day',
#  datetime.date(2018, 3, 9): 'Labor Day',
#  datetime.date(2018, 8, 10): 'Columbus Day',
#  datetime.date(2018, 11, 11): 'Veterans Day',
#  datetime.date(2018, 12, 11): 'Veterans Day observed',
#  datetime.date(2018, 11, 22): 'Thanksgiving Day',
#  datetime.date(2018, 12, 24): 'Christmas Eve',
#  datetime.date(2018, 12, 25): 'Christmas Day',
#  datetime.date(2019, 1, 1): "New Year's Day",
#  datetime.date(2019, 1, 21): '3tin Luther King Jr. Day',
#  datetime.date(2019, 2, 18): "Presidents' Day",
#  datetime.date(2019, 5, 27): 'Memorial Day',
#  datetime.date(2019, 4, 7): 'Independence Day',
#  datetime.date(2019, 2, 9): 'Labor Day',
#  datetime.date(2019, 10, 14): 'Columbus Day',
#  datetime.date(2019, 11, 11): 'Veterans Day',
#  datetime.date(2019, 11, 28): 'Thanksgiving Day',
#  datetime.date(2019, 12, 24): 'Christmas Eve',
#  datetime.date(2019, 12, 25): 'Christmas Day'}

# %%
# add holiday
us_acidents.insert(us_acidents.columns.get_loc('Start_Datetime'), 'Holiday', us_acidents['Start_Datetime'].dt.date.map(holidays_dict))
us_acidents['Holiday'] = us_acidents['Holiday'].fillna('Not Holiday')
us_acidents['Holiday'].value_counts()
# Out:
# Not Holiday                 47100
# Columbus Day                  176
# Presidents' Day               129
# Veterans Day                  126
# 3tin Luther King Jr. Day      115
# Veterans Day observed         104
# Labor Day                      95
# Independence Day               90
# Thanksgiving Day               82
# Christmas Eve                  79
# Memorial Day                   75
# Christmas Day                  53
# New Year's Day observed        36
# New Year's Day                 26
# Christmas Day observed          3
# Name: Holiday, dtype: int64

# %% [markdown]
# ##### Inserção do atributo WorkDay

# %%
# create a boolean mask by doing element-wise logical OR
work_days_mask = (us_acidents['Holiday'] != 'Not Holiday') | (us_acidents['WeekdayWeekend'] == 'Weekend')

# add work days
us_acidents.insert(us_acidents.columns.get_loc('Start_Datetime'), 'WorkDay', work_days_mask.map({False: 'Work Day', True: 'Not Work Day'}))
us_acidents['WorkDay'].value_counts()
# Out:
# Work Day        41843
# Not Work Day     6446
# Name: WorkDay, dtype: int64

# %%
us_acidents[us_acidents['WorkDay'] == 'Not Work Day'][['Start_Datetime', 'DayOfWeek', 'Holiday', 'WorkDay']].sample(5)
# Out:
#            Start_Datetime DayOfWeek      Holiday       WorkDay
# 27078 2018-06-17 10:16:34    Sunday  Not Holiday  Not Work Day
# 13352 2019-07-06 14:28:09  Saturday  Not Holiday  Not Work Day
# 44177 2019-03-10 16:45:05    Sunday  Not Holiday  Not Work Day
# 28475 2018-05-27 14:35:00    Sunday  Not Holiday  Not Work Day
# 12993 2019-08-25 14:44:46    Sunday  Not Holiday  Not Work Day

# %% [markdown]
# ##### Inserção do atributo SchoolBreak

# %%
school_holidays = pd.read_csv('school_holidays.csv', delimiter=';')
school_holidays['Start']= pd.to_datetime(school_holidays['Start'])
school_holidays['End']= pd.to_datetime(school_holidays['End'])

# %%
# initialize mask
classes_mask = pd.Series([False for _ in range(len(us_acidents))])

for i in range(len(school_holidays)):
    classes_mask |= (us_acidents['Start_Datetime'] >= school_holidays.loc[i, "Start"]) & (us_acidents['Start_Datetime'] <= school_holidays.loc[i, "End"])

# add school breaks
us_acidents.insert(us_acidents.columns.get_loc('Start_Datetime'), 'SchoolBreak', classes_mask.map(lambda x: 'No Classes' if x else 'Classes'))
us_acidents['SchoolBreak'].value_counts()
# Out:
# Classes       36532
# No Classes    10090
# Name: SchoolBreak, dtype: int64

# %% [markdown]
# ##### Inserção do atributo MoonCalendar

# %%
# add moon calendar --->> Não concluído
us_acidents.insert(us_acidents.columns.get_loc('Start_Datetime'), 'MoonCalendar', range(1, len(us_acidents) + 1))

# %% [markdown]
# >> Falta moon calendar

# %%
# create date dataframe
date_dimension = us_acidents.loc[:, 'DateKey':'MoonCalendar']

date_dimension.columns
# Out:
# Index(['DateKey', 'StartDay', 'StartMonth', 'StartYear', 'EndDay', 'EndMonth',
#        'EndYear', 'DayOfWeek', 'WeekdayWeekend', 'Quarter', 'WeekNumber',
#        'Holiday', 'WorkDay', 'SchoolBreak', 'MoonCalendar'],
#       dtype='object')

# %%
# drop unwanted data from the accidents dataframe
#us_acidents = us_acidents.drop(date_dimension.columns[1:], axis=1)

#us_acidents.columns

# %% [markdown]
# ### Weather Dimension
# * Definição de valores para dados meteorológicos nulos será feita com base na média de valores em cada atributo, ao nível da cidade,
# na respetiva semana em que ocorreu o acidente (tal será feito na criação da *dimension* Weather);

# %%
us_acidents[us_acidents["Region"].isna()]
# Out:
#               ID    TMC  Severity  DateKey  StartDay StartMonth  StartYear  \
# 4003    A-233367  201.0         2     3940        29   December       2016
# 4052    A-235363  201.0         3     3984        11    January       2017
# 4126    A-239332  201.0         2     4040         1   November       2016
# 4156    A-240858  201.0         3     4063         9   November       2016
# 4495    A-259189  241.0         2     4365        15       July       2016
# 6577    A-380661  201.0         3     6407         6      March       2017
# 8377    A-482621  201.0         2     8168        26       June       2017
# 8392    A-483466  201.0         2     8179         3       July       2017
# 8774    A-506941  241.0         3     8555        21       July       2017
# 9025    A-524285  201.0         2     8802         3   December       2019
# 12387   A-727551  201.0         2    12047         5  September       2019
# 13004   A-765861  241.0         2    12635        26     August       2019
# 13036   A-768402  201.0         2    12667        27     August       2019
# 13079   A-770974  201.0         2    12708        28     August       2019
# 13929   A-822498  201.0         2    13513        26       July       2019
# 13990   A-826053  201.0         2    13572        29       July       2019
# 14023   A-828046  201.0         2    13605        30       July       2019
# 14874   A-880343  201.0         2    14420        12       June       2019
# 15421   A-914246  201.0         2    14953        31        May       2019
# 15534   A-921066  201.0         2    15063         7        May       2019
# 16216   A-959891  201.0         2    15708        28        May       2019
# 16291   A-964366  241.0         2    15780        30        May       2019
# 16602   A-983286  201.0         2    16080         5      April       2019
# 16795   A-994799  201.0         2    16269        11      April       2019
# 17182  A-1018558  201.0         2    16643        24      April       2019
# 17806  A-1057509  201.0         2    17248        18      March       2019
# 22032  A-1302053  241.0         2    21264        20   November       2018
# 24072  A-1424173  201.0         2    23238        18  September       2018
# 27992  A-1654163  201.0         3    27013        13        May       2018
# 32737  A-1940245  201.0         2    31576         5   December       2017
# 34189  A-2026616  201.0         3    32965        18   November       2017
# 36156  A-2147844  201.0         2    34845        18  September       2017
# 36724  A-2182184  201.0         3    35377         1     August       2017
# 38754  A-2304435   -1.0         2    37307        16   November       2016
# 38798  A-2306811   -1.0         2    37347        23   November       2016
# 38829  A-2308183   -1.0         3    37375        29   November       2016
# 39059  A-2320992   -1.0         2    37592         8     August       2016
# 39075  A-2321615   -1.0         2    37607         9     August       2016
# 40255  A-2392292   -1.0         4    38761        30    January       2017
# 41459  A-2461278   -1.0         4    39932         8       June       2017
# 41835  A-2483739   -1.0         4    40301        24   December       2019
# 41991  A-2493988   -1.0         2    40456        31   December       2019
# 42929  A-2548571   -1.0         3    41389        22    October       2019
# 44339  A-2633776   -1.0         2    42790        28   February       2019
# 45838  A-2724335   -1.0         3    44251        29    October       2018
# 46599  A-2770181   -1.0         2    44996        19       June       2018
# 46772  A-2780126   -1.0         3    45166        15        May       2018
# 46962  A-2792767   -1.0         2    45348        19      April       2018
# 47353  A-2813420   -1.0         2    45728         7   February       2018
# 47538  A-2824195   -1.0         2    45905         3    January       2018
# 47716  A-2834313   -1.0         2    46076        24    January       2018
# 47887  A-2844282   -1.0         2    46237        13   December       2017
# 48316  A-2872230   -1.0         2    46649        25    October       2017
# 48548  A-2885926   -1.0         2    46871        31       July       2017
# 48948  A-2909476   -1.0         2    47264        22      April       2019
# 49036  A-2915112   -1.0         2    47348         6        May       2019
#
#        EndDay   EndMonth  EndYear  ... Roundabout Station   Stop  \
# 4003       29   December     2016  ...      False   False  False
# 4052       11    January     2017  ...      False   False  False
# 4126        1   November     2016  ...      False   False  False
# 4156        9   November     2016  ...      False   False  False
# 4495       15       July     2016  ...      False   False  False
# 6577        6      March     2017  ...      False   False  False
# 8377       26       June     2017  ...      False   False  False
# 8392        3       July     2017  ...      False   False  False
# 8774       21       July     2017  ...      False   False  False
# 9025        3   December     2019  ...      False   False  False
# 12387       5  September     2019  ...      False   False  False
# 13004      26     August     2019  ...      False   False  False
# 13036      27     August     2019  ...      False   False  False
# 13079      28     August     2019  ...      False   False  False
# 13929      26       July     2019  ...      False   False  False
# 13990      29       July     2019  ...      False   False  False
# 14023      30       July     2019  ...      False   False  False
# 14874      12       June     2019  ...      False   False  False
# 15421      31        May     2019  ...      False   False  False
# 15534       7        May     2019  ...      False   False  False
# 16216      28        May     2019  ...      False   False  False
# 16291      30        May     2019  ...      False   False  False
# 16602       5      April     2019  ...      False   False  False
# 16795      11      April     2019  ...      False   False  False
# 17182      24      April     2019  ...      False   False  False
# 17806      18      March     2019  ...      False    True  False
# 22032      20   November     2018  ...      False   False  False
# 24072      18  September     2018  ...      False    True  False
# 27992      13        May     2018  ...      False   False  False
# 32737       5   December     2017  ...      False   False  False
# 34189      18   November     2017  ...      False   False  False
# 36156      18  September     2017  ...      False   False  False
# 36724       1     August     2017  ...      False   False  False
# 38754      16   November     2016  ...      False   False  False
# 38798      23   November     2016  ...      False   False  False
# 38829      29   November     2016  ...      False   False  False
# 39059       8     August     2016  ...      False   False  False
# 39075       9     August     2016  ...      False   False  False
# 40255      30    January     2017  ...      False   False  False
# 41459       8       June     2017  ...      False    True  False
# 41835      24   December     2019  ...      False   False  False
# 41991      31   December     2019  ...      False   False  False
# 42929      22    October     2019  ...      False   False  False
# 44339      28   February     2019  ...      False   False  False
# 45838      29    October     2018  ...      False   False  False
# 46599      19       June     2018  ...      False   False  False
# 46772      15        May     2018  ...      False   False  False
# 46962      19      April     2018  ...      False   False  False
# 47353       7   February     2018  ...      False   False  False
# 47538       4    January     2018  ...      False   False  False
# 47716      24    January     2018  ...      False   False  False
# 47887      14   December     2017  ...      False   False  False
# 48316      25    October     2017  ...      False   False  False
# 48548      31       July     2017  ...      False   False  False
# 48948      22      April     2019  ...      False   False  False
# 49036       6        May     2019  ...      False   False  False
#
#        Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 4003             False          False        False            Day
# 4052             False          False        False            Day
# 4126             False           True        False            Day
# 4156             False          False        False            Day
# 4495             False          False        False            Day
# 6577             False          False        False            Day
# 8377             False          False        False            Day
# 8392             False           True        False            Day
# 8774             False          False        False          Night
# 9025             False           True        False          Night
# 12387            False           True        False            Day
# 13004            False          False        False            Day
# 13036            False           True        False            Day
# 13079            False           True        False            Day
# 13929            False           True        False          Night
# 13990            False          False        False            Day
# 14023            False           True        False            Day
# 14874            False          False        False            Day
# 15421            False          False        False            Day
# 15534            False          False        False            Day
# 16216            False           True        False            Day
# 16291            False          False        False            Day
# 16602            False           True        False          Night
# 16795            False          False        False            Day
# 17182            False           True        False            Day
# 17806            False           True        False            Day
# 22032            False          False        False          Night
# 24072            False           True        False            Day
# 27992            False          False        False            Day
# 32737            False           True        False          Night
# 34189            False          False        False            Day
# 36156            False          False        False            Day
# 36724            False          False        False            Day
# 38754            False          False        False            Day
# 38798            False          False        False            Day
# 38829            False          False        False          Night
# 39059            False          False        False            Day
# 39075            False          False        False            Day
# 40255            False           True        False            Day
# 41459            False           True        False            Day
# 41835            False          False        False          Night
# 41991            False          False        False            Day
# 42929            False           True        False            Day
# 44339            False          False        False          Night
# 45838            False          False        False            Day
# 46599            False          False        False            Day
# 46772            False          False        False          Night
# 46962            False           True        False            Day
# 47353            False          False        False          Night
# 47538            False          False        False          Night
# 47716            False          False        False          Night
# 47887            False          False        False          Night
# 48316            False          False        False          Night
# 48548            False          False        False            Day
# 48948            False          False        False            Day
# 49036            False          False        False          Night
#
#        Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 4003              Day               Day                   Day
# 4052              Day               Day                   Day
# 4126              Day               Day                   Day
# 4156              Day               Day                   Day
# 4495              Day               Day                   Day
# 6577              Day               Day                   Day
# 8377              Day               Day                   Day
# 8392              Day               Day                   Day
# 8774            Night               Day                   Day
# 9025            Night             Night                 Night
# 12387             Day               Day                   Day
# 13004             Day               Day                   Day
# 13036             Day               Day                   Day
# 13079             Day               Day                   Day
# 13929           Night               Day                   Day
# 13990             Day               Day                   Day
# 14023             Day               Day                   Day
# 14874             Day               Day                   Day
# 15421             Day               Day                   Day
# 15534             Day               Day                   Day
# 16216             Day               Day                   Day
# 16291             Day               Day                   Day
# 16602           Night             Night                   Day
# 16795             Day               Day                   Day
# 17182             Day               Day                   Day
# 17806             Day               Day                   Day
# 22032           Night             Night                 Night
# 24072             Day               Day                   Day
# 27992             Day               Day                   Day
# 32737             Day               Day                   Day
# 34189             Day               Day                   Day
# 36156             Day               Day                   Day
# 36724             Day               Day                   Day
# 38754             Day               Day                   Day
# 38798             Day               Day                   Day
# 38829           Night               Day                   Day
# 39059             Day               Day                   Day
# 39075             Day               Day                   Day
# 40255             Day               Day                   Day
# 41459             Day               Day                   Day
# 41835           Night             Night                 Night
# 41991             Day               Day                   Day
# 42929             Day               Day                   Day
# 44339           Night             Night                   Day
# 45838             Day               Day                   Day
# 46599             Day               Day                   Day
# 46772             Day               Day                   Day
# 46962             Day               Day                   Day
# 47353           Night               Day                   Day
# 47538           Night             Night                   Day
# 47716           Night             Night                 Night
# 47887           Night             Night                 Night
# 48316           Night               Day                   Day
# 48548             Day               Day                   Day
# 48948             Day               Day                   Day
# 49036             Day               Day                   Day
#
# [56 rows x 58 columns]

# %%
us_acidents[["Temperature(F)", "State", "WeekNumber", "StartYear"]].sort_values(by=['State', 'WeekNumber', 'StartYear'], ascending=True)
# Out:
#        Temperature(F)    State  WeekNumber  StartYear
# 21240            73.4  Alabama           1       2018
# 21241            69.8  Alabama           1       2018
# 31628            24.6  Alabama           1       2018
# 19324            55.0  Alabama           1       2019
# 19325            52.0  Alabama           1       2019
# ...               ...      ...         ...        ...
# 49241            34.0  Wyoming          18       2019
# 38189            77.7  Wyoming          39       2016
# 45767            33.1  Wyoming          43       2018
# 34293            44.6  Wyoming          47       2017
# 22191            21.2  Wyoming          47       2018
#
# [48289 rows x 4 columns]

# %% [markdown]
# #### Discretização dos valores contínuos referentes a meteorologia

# %%
def discretize_humidity(x):
    if x <= 25.0:
        return '(Low) rate <= 25.0'
    elif 25.0 < x <= 50.0:
        return '(Medium) 25.0 < rate <= 50.0'
    elif 50.0 < x <= 75.0:
        return '(High) 50.0 < rate <= 75.0'
    else:
        return '(Very High) rate > 75.0'

def discretize_temp(x):
    if x <= 32.0:
        return '(Cold) temp <= 32.0'
    elif 32.0 < x <= 50.0:
        return '(Low) 32.0 < temp <= 50.0'
    elif 50.0 < x <= 80.0:
        return '(Moderate) 50.0 < temp <= 80.0'
    elif 80.0 < x <= 100.0:
        return '(Warm) 80.0 < temp <= 100.0'
    else:
        return "(Hot) temp > 100.0"

def discretize_visibility(x):
    if x <= 1.0:
        return '(Low) visibility <= 1.0'
    elif 1.0 < x <= 2.0:
        return '(Reduced) 1.0 < visibility <= 2.0'
    elif 2.0 < x <= 5.0:
        return '(Moderate) 2.0 < visibility <= 5.0'
    elif 5.0 < x <= 20.0:
        return '(Good) 5.0 < visibility <= 20.0'
    elif 20.0 < x <= 50.0:
        return '(Very Good) 20.0 < visibility <= 50.0'
    else:
        return '(Excellent) visibility > 50.0'

#https://en.wikipedia.org/wiki/Beaufort_scale - converting m/s to mph
def discretize_windspeed(x):
    if x <= 1.12:
        return '(Calm) speed <= 1.0'
    elif 1.12 < x <= 3.36:
        return '(Light Air) 1.12 < speed <= 3.36'
    elif 3.36 < x <= 7.38:
        return '(Light Breeze) 3.36 < speed <= 7.38'
    elif 7.38 < x <= 12.30:
        return '(Gentle Breeze) 7.38 < speed <= 12.30'
    elif 12.30 < x <= 17.67:
        return '(Moderate Breeze) 12.30 < speed <= 17.67'
    elif 17.67 < x <= 23.93:
        return '(Fresh Breeze) 17.67 < speed <= 23.93'
    elif 23.93 < x <= 30.87:
        return '(Strong Breeze) 23.93 < speed <= 30.87'
    elif 30.87 < x <= 38.25:
        return '(High Wind)30.87 < speed <= 38.25'
    elif 38.25 < x <= 46.30:
        return '(Gale) 38.25 < speed <= 46.30'
    elif 46.30 < x <= 54.58:
        return '(Strong Gale) 46.30 < speed <= 54.58'
    elif 54.58 < x <= 63.53:
        return '(Storm) 54.58 < speed <= 63.53'
    elif 63.53 < x <= 72.92:
        return '(Violent Storm) 63.53 < speed <= 72.92' 
    else:
        return '(Hurricane) speed > 72.92'

# https://en.wikipedia.org/wiki/Rain#Intensity
def discretize_rainfall(x):
    if x <= 0.1:
        return '(Light) rate <= 0.1'
    elif 0.1 < x <= 0.39:
        return '(Moderate) 0.1 < rate <= 0.3'
    elif 0.39 < x <= 2.0:
        return '(Heavy) 0.39 < rate <= 2.0'
    else:
        return '(Violent) rate > 2.0'

us_acidents['Temperature(F)'] = us_acidents["Temperature(F)"].map(discretize_temp)
us_acidents['Humidity(%)'] = us_acidents['Humidity(%)'].map(discretize_humidity)
us_acidents['Visibility(mi)'] = us_acidents['Visibility(mi)'].map(discretize_visibility)
us_acidents['Wind_Speed(mph)'] = us_acidents['Wind_Speed(mph)'].map(discretize_windspeed)
us_acidents['Precipitation(in)'] = us_acidents['Precipitation(in)'].map(discretize_rainfall)

# %% [markdown]
# #### LocalTime Dimension

# %%
us_acidents['LocalTimeKey'] = pd.RangeIndex(start=1, stop=us_acidents.shape[0]+1)

# %%
us_acidents['LocalTimeKey']
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 49995    48285
# 49996    48286
# 49997    48287
# 49998    48288
# 49999    48289
# Name: LocalTimeKey, Length: 48289, dtype: int64

# %%
us_acidents['StartTime'] = pd.DatetimeIndex(us_acidents['Start_Datetime']).time
us_acidents['EndTime'] = pd.DatetimeIndex(us_acidents['End_Datetime']).time

# %%
def define_period_of_day(start_hour, civil_tw, naut_tw, ast_tw, sunrise_sunset) :
    if (civil_tw != naut_tw) or (naut_tw != ast_tw) :
        return "Dusk"
    elif dt.time(8, 0, 0) < start_hour < dt.time(10, 0, 0) :
        return 'Morning Rush Hour'
    elif dt.time(12, 30, 0) < start_hour < dt.time(14, 30, 0) :
        return 'Lunch Time'
    elif dt.time(16, 0, 0) < start_hour < dt.time(18, 0, 0) :
        return 'Evening Rush Hour'
    else:
        return sunrise_sunset

us_acidents['PeriodOfDay'] = us_acidents.apply(lambda x: define_period_of_day(x['StartTime'], x['Civil_Twilight'], x['Nautical_Twilight'], x['Astronomical_Twilight'], x['Sunrise_Sunset']), axis=1)

# %%
localtime_dimension = us_acidents[['LocalTimeKey', 'StartTime', 'PeriodOfDay', 'Timezone', 'EndTime']]

# %%
#us_acidents.drop(['PeriodOfDay', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight'], axis=1, inplace=True)
us_acidents.columns
# Out:
# Index(['ID', 'TMC', 'Severity', 'DateKey', 'StartDay', 'StartMonth',
#        'StartYear', 'EndDay', 'EndMonth', 'EndYear', 'DayOfWeek',
#        'WeekdayWeekend', 'Quarter', 'WeekNumber', 'Holiday', 'WorkDay',
#        'SchoolBreak', 'MoonCalendar', 'Start_Datetime', 'End_Datetime',
#        'Distance(mi)', 'LocationKey', 'Street', 'City', 'County', 'State',
#        'Region', 'Subregion', 'AlcoholConsumptionRate', 'VehicleRegistrations',
#        'UrbanRuralClassification', 'MaximumSpeedLimit', 'Timezone',
#        'Temperature(F)', 'Humidity(%)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'POI_Key',
#        'Amenity', 'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight',
#        'Nautical_Twilight', 'Astronomical_Twilight', 'LocalTimeKey',
#        'StartTime', 'EndTime', 'PeriodOfDay'],
#       dtype='object')

# %% [markdown]
# #### StandardTime Dimension
#
# * StandardTimeKey
# * StartHour (no timezone Standard)
# * EndHour (no timezone Standard)
# * StandardTimeZone (GMT?)

# %%
us_acidents["Timezone"].value_counts()
# Out:
# US/Eastern     20776
# US/Pacific     13651
# US/Central     11248
# US/Mountain     2614
# Name: Timezone, dtype: int64

# %%
# Creating the Standard Time Key
us_acidents['StandardTimeKey'] = pd.RangeIndex(start=1, stop=us_acidents.shape[0]+1)

# %%
import pytz

def convert_timezone(timestamp, old_timezone, new_timezone) :
    localized_timestamp = pytz.timezone(old_timezone).localize(timestamp)
    new_timezone_timestamp = localized_timestamp.astimezone(pytz.timezone(new_timezone))
    return dt.time(new_timezone_timestamp.hour, new_timezone_timestamp.minute, new_timezone_timestamp.second)

us_acidents['StandardStartTime'] = us_acidents.apply(lambda x: convert_timezone(x['Start_Datetime'], x['Timezone'], "Etc/GMT"), axis=1)
us_acidents['StandardEndTime'] = us_acidents.apply(lambda x: convert_timezone(x['End_Datetime'], x['Timezone'], "Etc/GMT"), axis=1)

# %%
us_acidents["Standard_Timezone"] = "GMT"
us_acidents[['StandardTimeKey','StartTime','EndTime','Timezone','StandardStartTime','StandardEndTime', 'Standard_Timezone']]
standardtime_dimension = us_acidents[['StandardTimeKey', 'StandardStartTime','StandardEndTime', 'Standard_Timezone']]
#us_acidents.drop(['Start_Datetime', 'End_Datetime', 'Timezone', 'StartTime', 'EndTime', 'StandardStartTime', 'StandardEndTime', 'Standard_Timezone'], axis=1, inplace=True)
us_acidents.columns

# %%
standardtime_dimension
