# %% [markdown]
# ### Star Schema

# %%
from PIL import Image
import requests
import matplotlib.pyplot as plt

# Corrigir import do star schema
url = 'https://i.imgur.com/1prxQ4H.png'
response = requests.get(url, stream=True)
img = Image.open(response.raw)

plt.imshow(img)
plt.show()

# %% [markdown]
# ### Importação dos datasets relevantes ao problema
#
# Datasets a importar:
# * US Accidents
# * TMC's e eventos associados
# * Calendário com fases da lua (\*)
# * Limite máximo de velocidade por estado
# * Dados de consumo de álcool por estado
# * Quantidade de automóveis registados por estado

# %%
import pandas as pd
import re
from datetime import datetime

# %% [markdown]
# ##### Importação do dataset US Accidents

# %%
# Import us accidents dataset
us_acidents = pd.read_csv('US_Accidents_Dec19.csv')
us_acidents[:5]
# Out:
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# 0  39.865147 -84.058723      NaN      NaN  ...       False   False  False
# 1  39.928059 -82.831184      NaN      NaN  ...       False   False  False
# 2  39.063148 -84.032608      NaN      NaN  ...       False   False  False
# 3  39.747753 -84.205582      NaN      NaN  ...       False   False  False
# 4  39.627781 -84.188354      NaN      NaN  ...       False   False  False
#
#   Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0           False          False        False          Night          Night
# 1           False          False        False          Night          Night
# 2           False           True        False          Night          Night
# 3           False          False        False          Night            Day
# 4           False           True        False            Day            Day
#
#   Nautical_Twilight Astronomical_Twilight
# 0             Night                 Night
# 1             Night                   Day
# 2               Day                   Day
# 3               Day                   Day
# 4               Day                   Day
#
# [5 rows x 49 columns]

# %% [markdown]
# ##### Importação do dataset relativo a TMCs / Criação da Dimensão TMC

# %%
# import event codes
event_code = pd.read_csv('event_code_tmc.csv', delimiter=';')
event_code = event_code.rename(columns={"Code": "TMC_Key", "Description":"Event"})

# add out-of-range key
event_code = event_code.append({'TMC_Key': -1, 'Event': 'unidentified'}, ignore_index=True)
event_code[:5]
# Out:
#    TMC_Key                                              Event
# 0        1                                    traffic problem
# 1        2  queuing traffic (with average speeds Q). Dange...
# 2       11                overheight warning system triggered
# 3       12  (Q) accident(s), traffic being directed around...
# 4       16       closed, rescue and recovery work in progress

# %% [markdown]
# ##### Importação do dataset sobre consumo de álcool

# %%
# import alcohool consumption rates by state
alcohol_consumption = pd.read_csv('alcohol_consumption_state.csv', delimiter=';')

alcohol_consumption.at[20, "State"] = "Massachusetts"

alcohol_consumption.loc[alcohol_consumption['rate'].apply(lambda x : x <= 2.0), 'discretizeRate'] = 'Low'
alcohol_consumption.loc[alcohol_consumption['rate'].apply(lambda x : (x > 2.0) & (x <= 2.5)), 'discretizeRate'] = 'Medium'
alcohol_consumption.loc[alcohol_consumption['rate'].apply(lambda x : (x > 2.5) & (x <= 3.5)), 'discretizeRate'] = 'High'
alcohol_consumption.loc[alcohol_consumption['rate'].apply(lambda x : x > 3.5), 'discretizeRate'] = 'Very High'

alcohol_consumption = alcohol_consumption.sort_values(by=['rate'], ascending=False)
print(alcohol_consumption[:5])

# Create dictionary where each key corresponds to a state' rate of alcoholism
alcohol_dict = pd.Series(alcohol_consumption['discretizeRate'].values,index=alcohol_consumption['State']).to_dict()
alcohol_dict
# Out:
#             State  rate discretizeRate
# 28  New Hampshire  4.74      Very High
# 7        Delaware  3.60      Very High
# 27         Nevada  3.43           High
# 33   North Dakota  3.15           High
# 25        Montana  3.11           High
# {'New Hampshire': 'Very High',
#  'Delaware': 'Very High',
#  'Nevada': 'High',
#  'North Dakota': 'High',
#  'Montana': 'High',
#  'Vermont': 'High',
#  'Wisconsin': 'High',
#  'Idaho': 'High',
#  'South Dakota': 'High',
#  'Colorado': 'High',
#  'Maine': 'High',
#  'Alaska': 'High',
#  'Minnesota': 'High',
#  'Oregon': 'High',
#  'Wyoming': 'High',
#  'Hawaii': 'High',
#  'Florida': 'High',
#  'Rhode Island': 'High',
#  'Massachusetts': 'High',
#  'Louisiana': 'High',
#  'Missouri': 'High',
#  'Connecticut': 'Medium',
#  'Iowa': 'Medium',
#  'Illinois': 'Medium',
#  'Texas': 'Medium',
#  'Pennsylvania': 'Medium',
#  'Michigan': 'Medium',
#  'New Jersey': 'Medium',
#  'California': 'Medium',
#  'Arizona': 'Medium',
#  'Washington': 'Medium',
#  'Nebraska': 'Medium',
#  'Mississippi': 'Medium',
#  'New York': 'Medium',
#  'South Carolina': 'Medium',
#  'New Mexico': 'Medium',
#  'North Carolina': 'Medium',
#  'Maryland': 'Medium',
#  'Virginia': 'Medium',
#  'Indiana': 'Medium',
#  'Tennessee': 'Medium',
#  'Ohio': 'Medium',
#  'Alabama': 'Low',
#  'Kentucky': 'Low',
#  'Kansas': 'Low',
#  'Georgia': 'Low',
#  'Oklahoma': 'Low',
#  'Arkansas': 'Low',
#  'West Virginia': 'Low',
#  'Utah': 'Low'}

# %% [markdown]
# ##### Importação do dataset sobre registos automóveis

# %%
# import vehicle registrations by state
vehicle_registration = pd.read_csv('vehicle_registrations_usa.csv',delimiter=';')
vehicle_registration = vehicle_registration[vehicle_registration['State'] != 'Dist. of Col.'].reset_index(drop=True)

vehicle_registration.at[4, "State"] = "California"
vehicle_registration.at[6, "State"] = "Connecticut"


for i in range(len(vehicle_registration.index)):
    vehicle_registration.at[i, "Total"] = int(re.sub(' ', '', vehicle_registration.loc[i]["Total"]))

vehicle_registration = vehicle_registration.sort_values(by=['Total'], ascending=False)

vehicle_registration.loc[vehicle_registration['Total'].apply(lambda x : x <= 5000000), 'discretizeTotal'] = 'Low'
vehicle_registration.loc[vehicle_registration['Total'].apply(lambda x : (x > 5000000) & (x <= 10000000)), 'discretizeTotal'] = 'Medium'
vehicle_registration.loc[vehicle_registration['Total'].apply(lambda x : (x > 10000000) & (x <= 20000000)), 'discretizeTotal'] = 'High'
vehicle_registration.loc[vehicle_registration['Total'].apply(lambda x : x > 20000000), 'discretizeTotal'] = 'Very High'

print(vehicle_registration[:5])

vehicle_dict = pd.Series(vehicle_registration['discretizeTotal'].values,index=vehicle_registration['State']).to_dict()
vehicle_dict
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-e785b0fb3540> in <module>
#       8
#       9 for i in range(len(vehicle_registration.index)):
# ---> 10     vehicle_registration.at[i, "Total"] = int(re.sub(' ', '', vehicle_registration.loc[i]["Total"]))
#      11
#      12 vehicle_registration = vehicle_registration.sort_values(by=['Total'], ascending=False)
#
# C:\Anaconda\lib\re.py in sub(pattern, repl, string, count, flags)
#     190     a callable, it's passed the Match object and must return
#     191     a replacement string to be used."""
# --> 192     return _compile(pattern, flags).sub(repl, string, count)
#     193
#     194 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: cannot use a string pattern on a bytes-like object

# %% [markdown]
# ##### Importação do dataset sobre nível de urbanização

# %%
# import rural/urban information about counties
urban = pd.read_excel('NCHSURCodes2013.xlsx')

# drop unwanted information
urban = urban.drop(['State Abr.','CBSA title', 'CBSA 2012 pop', 'County 2012 pop'], axis=1)

for i in range(len(urban.index)):
    urban.at[i, "County name"] = re.sub(' County', '', urban.loc[i]["County name"])
    
urban_term = {1:'Large Central Metro',
              2:'Large Fringe Metro',
              3:'Medium Metro',
              4:'Small Metro',
              5:'Micropolitan',
              6:'Non-Core'}

urban["2013 code"] = urban["2013 code"].map(urban_term)

urban["County name"] = urban["County name"].replace('DeSoto', 'De Soto')
urban["County name"] = urban["County name"].replace('St. Lucie', 'Saint Lucie')
urban["County name"] = urban["County name"].replace('DeKalb', 'Dekalb')


urban_dict = pd.Series(urban['2013 code'].values,index=urban['County name']).to_dict()
urban_dict
# Out:
# {'Autauga': 'Medium Metro',
#  'Baldwin': 'Micropolitan',
#  'Barbour': 'Non-Core',
#  'Bibb': 'Small Metro',
#  'Blount': 'Medium Metro',
#  'Bullock': 'Non-Core',
#  'Butler': 'Large Fringe Metro',
#  'Calhoun': 'Non-Core',
#  'Chambers': 'Large Fringe Metro',
#  'Cherokee': 'Micropolitan',
#  'Chilton': 'Large Fringe Metro',
#  'Choctaw': 'Non-Core',
#  'Clarke': 'Large Fringe Metro',
#  'Clay': 'Small Metro',
#  'Cleburne': 'Non-Core',
#  'Coffee': 'Micropolitan',
#  'Colbert': 'Small Metro',
#  'Conecuh': 'Non-Core',
#  'Coosa': 'Micropolitan',
#  'Covington': 'Non-Core',
#  'Crenshaw': 'Non-Core',
#  'Cullman': 'Micropolitan',
#  'Dale': 'Micropolitan',
#  'Dallas': 'Large Central Metro',
#  'Dekalb': 'Non-Core',
#  'Elmore': 'Micropolitan',
#  'Escambia': 'Medium Metro',
#  'Etowah': 'Small Metro',
#  'Fayette': 'Small Metro',
#  'Franklin': 'Medium Metro',
#  'Geneva': 'Small Metro',
#  'Greene': 'Small Metro',
#  'Hale': 'Micropolitan',
#  'Henry': 'Micropolitan',
#  'Houston': 'Non-Core',
#  'Jackson': 'Non-Core',
#  'Jefferson': 'Micropolitan',
#  'Lamar': 'Micropolitan',
#  'Lauderdale': 'Non-Core',
#  'Lawrence': 'Micropolitan',
#  'Lee': 'Non-Core',
#  'Limestone': 'Non-Core',
#  'Lowndes': 'Micropolitan',
#  'Macon': 'Large Fringe Metro',
#  'Madison': 'Non-Core',
#  'Marengo': 'Non-Core',
#  'Marion': 'Micropolitan',
#  'Marshall': 'Small Metro',
#  'Mobile': 'Medium Metro',
#  'Monroe': 'Non-Core',
#  'Montgomery': 'Small Metro',
#  'Morgan': 'Non-Core',
#  'Perry': 'Non-Core',
#  'Pickens': 'Medium Metro',
#  'Pike': 'Large Fringe Metro',
#  'Randolph': 'Micropolitan',
#  'Russell': 'Non-Core',
#  'St. Clair': 'Non-Core',
#  'Shelby': 'Non-Core',
#  'Sumter': 'Small Metro',
#  'Talladega': 'Micropolitan',
#  'Tallapoosa': 'Non-Core',
#  'Tuscaloosa': 'Small Metro',
#  'Walker': 'Micropolitan',
#  'Washington': 'Large Fringe Metro',
#  'Wilcox': 'Non-Core',
#  'Winston': 'Non-Core',
#  'Aleutians East Borough': 'Non-Core',
#  'Aleutians West Census Area': 'Non-Core',
#  'Anchorage Municipality': 'Medium Metro',
#  'Bethel Census Area': 'Non-Core',
#  'Bristol Bay Borough': 'Non-Core',
#  'Denali Borough': 'Non-Core',
#  'Dillingham Census Area': 'Non-Core',
#  'Fairbanks North Star Borough': 'Small Metro',
#  'Haines Borough': 'Non-Core',
#  'Hoonah-Angoon Census Area': 'Non-Core',
#  'Juneau City and Borough': 'Micropolitan',
#  'Kenai Peninsula Borough': 'Non-Core',
#  'Ketchikan Gateway Borough': 'Micropolitan',
#  'Kodiak Island Borough': 'Non-Core',
#  'Kusilvak Census Area': 'Non-Core',
#  'Lake and Peninsula Borough': 'Non-Core',
#  'Matanuska-Susitna Borough': 'Medium Metro',
#  'Nome Census Area': 'Non-Core',
#  'North Slope Borough': 'Non-Core',
#  'Northwest Arctic Borough': 'Non-Core',
#  'Petersburg Census Area': 'Non-Core',
#  'Prince of Wales-Hyder Census Area': 'Non-Core',
#  'Prince of Wales-Outer Ket': 'Non-Core',
#  'Sitka City and Borough': 'Non-Core',
#  'Skagway Municipality': 'Non-Core',
#  'Skagway-Hoonah-Angoon Census Area': 'Non-Core',
#  'Southeast Fairbanks Census Area': 'Non-Core',
#  'Valdez-Cordova Census Area': 'Non-Core',
#  'Wade Hampton Census Area': 'Non-Core',
#  'Wrangell City and Borough': 'Non-Core',
#  'Wrangell-Petersburg Census Area': 'Non-Core',
#  'Yakutat City and Borough': 'Non-Core',
#  'Yukon-Koyukuk Census Area': 'Non-Core',
#  'Apache': 'Non-Core',
#  'Cochise': 'Small Metro',
#  'Coconino': 'Small Metro',
#  'Gila': 'Micropolitan',
#  'Graham': 'Non-Core',
#  'Greenlee': 'Non-Core',
#  'La Paz': 'Non-Core',
#  'Maricopa': 'Large Central Metro',
#  'Mohave': 'Small Metro',
#  'Navajo': 'Micropolitan',
#  'Pima': 'Medium Metro',
#  'Pinal': 'Large Fringe Metro',
#  'Santa Cruz': 'Medium Metro',
#  'Yavapai': 'Small Metro',
#  'Yuma': 'Non-Core',
#  'Arkansas': 'Non-Core',
#  'Ashley': 'Non-Core',
#  'Baxter': 'Micropolitan',
#  'Benton': 'Medium Metro',
#  'Boone': 'Small Metro',
#  'Bradley': 'Small Metro',
#  'Carroll': 'Non-Core',
#  'Chicot': 'Non-Core',
#  'Clark': 'Non-Core',
#  'Cleveland': 'Large Fringe Metro',
#  'Columbia': 'Medium Metro',
#  'Conway': 'Non-Core',
#  'Craighead': 'Small Metro',
#  'Crawford': 'Non-Core',
#  'Crittenden': 'Non-Core',
#  'Cross': 'Non-Core',
#  'Desha': 'Non-Core',
#  'Drew': 'Non-Core',
#  'Faulkner': 'Medium Metro',
#  'Fulton': 'Non-Core',
#  'Garland': 'Small Metro',
#  'Grant': 'Micropolitan',
#  'Hempstead': 'Non-Core',
#  'Hot Spring': 'Micropolitan',
#  'Howard': 'Micropolitan',
#  'Independence': 'Micropolitan',
#  'Izard': 'Non-Core',
#  'Johnson': 'Non-Core',
#  'Lafayette': 'Non-Core',
#  'Lincoln': 'Non-Core',
#  'Little River': 'Small Metro',
#  'Logan': 'Micropolitan',
#  'Lonoke': 'Medium Metro',
#  'Miller': 'Non-Core',
#  'Mississippi': 'Non-Core',
#  'Nevada': 'Micropolitan',
#  'Newton': 'Medium Metro',
#  'Ouachita': 'Micropolitan',
#  'Phillips': 'Non-Core',
#  'Poinsett': 'Small Metro',
#  'Polk': 'Non-Core',
#  'Pope': 'Non-Core',
#  'Prairie': 'Non-Core',
#  'Pulaski': 'Small Metro',
#  'St. Francis': 'Micropolitan',
#  'Saline': 'Non-Core',
#  'Scott': 'Medium Metro',
#  'Searcy': 'Non-Core',
#  'Sebastian': 'Medium Metro',
#  'Sevier': 'Non-Core',
#  'Sharp': 'Non-Core',
#  'Stone': 'Micropolitan',
#  'Union': 'Medium Metro',
#  'Van Buren': 'Non-Core',
#  'White': 'Non-Core',
#  'Woodruff': 'Non-Core',
#  'Yell': 'Micropolitan',
#  'Alameda': 'Large Central Metro',
#  'Alpine': 'Non-Core',
#  'Amador': 'Non-Core',
#  'Butte': 'Non-Core',
#  'Calaveras': 'Non-Core',
#  'Colusa': 'Non-Core',
#  'Contra Costa': 'Large Fringe Metro',
#  'Del Norte': 'Micropolitan',
#  'El Dorado': 'Large Fringe Metro',
#  'Fresno': 'Medium Metro',
#  'Glenn': 'Non-Core',
#  'Humboldt': 'Micropolitan',
#  'Imperial': 'Small Metro',
#  'Inyo': 'Non-Core',
#  'Kern': 'Medium Metro',
#  'Kings': 'Large Central Metro',
#  'Lake': 'Non-Core',
#  'Lassen': 'Micropolitan',
#  'Los Angeles': 'Large Central Metro',
#  'Madera': 'Small Metro',
#  'Marin': 'Large Fringe Metro',
#  'Mariposa': 'Non-Core',
#  'Mendocino': 'Micropolitan',
#  'Merced': 'Medium Metro',
#  'Modoc': 'Non-Core',
#  'Mono': 'Non-Core',
#  'Monterey': 'Medium Metro',
#  'Napa': 'Small Metro',
#  'Orange': 'Non-Core',
#  'Placer': 'Large Fringe Metro',
#  'Plumas': 'Non-Core',
#  'Riverside': 'Large Central Metro',
#  'Sacramento': 'Large Central Metro',
#  'San Benito': 'Large Fringe Metro',
#  'San Bernardino': 'Large Fringe Metro',
#  'San Diego': 'Large Central Metro',
#  'San Francisco': 'Large Central Metro',
#  'San Joaquin': 'Medium Metro',
#  'San Luis Obispo': 'Medium Metro',
#  'San Mateo': 'Large Fringe Metro',
#  'Santa Barbara': 'Medium Metro',
#  'Santa Clara': 'Large Central Metro',
#  'Shasta': 'Small Metro',
#  'Sierra': 'Non-Core',
#  'Siskiyou': 'Non-Core',
#  'Solano': 'Medium Metro',
#  'Sonoma': 'Medium Metro',
#  'Stanislaus': 'Medium Metro',
#  'Sutter': 'Small Metro',
#  'Tehama': 'Micropolitan',
#  'Trinity': 'Micropolitan',
#  'Tulare': 'Medium Metro',
#  'Tuolumne': 'Micropolitan',
#  'Ventura': 'Medium Metro',
#  'Yolo': 'Large Fringe Metro',
#  'Yuba': 'Small Metro',
#  'Adams': 'Non-Core',
#  'Alamosa': 'Non-Core',
#  'Arapahoe': 'Large Fringe Metro',
#  'Archuleta': 'Non-Core',
#  'Baca': 'Non-Core',
#  'Bent': 'Non-Core',
#  'Boulder': 'Medium Metro',
#  'Broomfield': 'Large Fringe Metro',
#  'Chaffee': 'Non-Core',
#  'Cheyenne': 'Non-Core',
#  'Clear Creek': 'Large Fringe Metro',
#  'Conejos': 'Non-Core',
#  'Costilla': 'Non-Core',
#  'Crowley': 'Non-Core',
#  'Custer': 'Small Metro',
#  'Delta': 'Non-Core',
#  'Denver': 'Large Central Metro',
#  'Dolores': 'Non-Core',
#  'Douglas': 'Medium Metro',
#  'Eagle': 'Micropolitan',
#  'Elbert': 'Non-Core',
#  'El Paso': 'Medium Metro',
#  'Fremont': 'Micropolitan',
#  'Garfield': 'Non-Core',
#  'Gilpin': 'Large Fringe Metro',
#  'Grand': 'Non-Core',
#  'Gunnison': 'Non-Core',
#  'Hinsdale': 'Non-Core',
#  'Huerfano': 'Non-Core',
#  'Kiowa': 'Non-Core',
#  'Kit Carson': 'Non-Core',
#  'La Plata': 'Micropolitan',
#  'Larimer': 'Medium Metro',
#  'Las Animas': 'Non-Core',
#  'Mesa': 'Small Metro',
#  'Mineral': 'Small Metro',
#  'Moffat': 'Micropolitan',
#  'Montezuma': 'Non-Core',
#  'Montrose': 'Micropolitan',
#  'Otero': 'Micropolitan',
#  'Ouray': 'Non-Core',
#  'Park': 'Non-Core',
#  'Pitkin': 'Micropolitan',
#  'Prowers': 'Non-Core',
#  'Pueblo': 'Small Metro',
#  'Rio Blanco': 'Non-Core',
#  'Rio Grande': 'Non-Core',
#  'Routt': 'Micropolitan',
#  'Saguache': 'Non-Core',
#  'San Juan': 'Non-Core',
#  'San Miguel': 'Micropolitan',
#  'Sedgwick': 'Medium Metro',
#  'Summit': 'Micropolitan',
#  'Teller': 'Medium Metro',
#  'Weld': 'Medium Metro',
#  'Fairfield': 'Medium Metro',
#  'Hartford': 'Large Central Metro',
#  'Litchfield': 'Micropolitan',
#  'Middlesex': 'Non-Core',
#  'New Haven': 'Medium Metro',
#  'New London': 'Medium Metro',
#  'Tolland': 'Large Fringe Metro',
#  'Windham': 'Non-Core',
#  'Kent': 'Non-Core',
#  'New Castle': 'Large Fringe Metro',
#  'Sussex': 'Large Fringe Metro',
#  'District of Columbia': 'Large Central Metro',
#  'Alachua': 'Medium Metro',
#  'Baker': 'Non-Core',
#  'Bay': 'Small Metro',
#  'Bradford': 'Micropolitan',
#  'Brevard': 'Medium Metro',
#  'Broward': 'Large Fringe Metro',
#  'Charlotte': 'Non-Core',
#  'Citrus': 'Small Metro',
#  'Collier': 'Medium Metro',
#  'De Soto': 'Large Fringe Metro',
#  'Dixie': 'Non-Core',
#  'Duval': 'Non-Core',
#  'Flagler': 'Medium Metro',
#  'Gadsden': 'Medium Metro',
#  'Gilchrist': 'Medium Metro',
#  'Glades': 'Non-Core',
#  'Gulf': 'Small Metro',
#  'Hamilton': 'Non-Core',
#  'Hardee': 'Micropolitan',
#  'Hendry': 'Micropolitan',
#  'Hernando': 'Large Fringe Metro',
#  'Highlands': 'Small Metro',
#  'Hillsborough': 'Medium Metro',
#  'Holmes': 'Non-Core',
#  'Indian River': 'Small Metro',
#  'Leon': 'Non-Core',
#  'Levy': 'Non-Core',
#  'Liberty': 'Large Fringe Metro',
#  'Manatee': 'Medium Metro',
#  'Martin': 'Small Metro',
#  'Miami-Dade': 'Large Central Metro',
#  'Nassau': 'Large Fringe Metro',
#  'Okaloosa': 'Small Metro',
#  'Okeechobee': 'Micropolitan',
#  'Osceola': 'Non-Core',
#  'Palm Beach': 'Large Fringe Metro',
#  'Pasco': 'Large Fringe Metro',
#  'Pinellas': 'Large Central Metro',
#  'Putnam': 'Medium Metro',
#  'St. Johns': 'Large Fringe Metro',
#  'Saint Lucie': 'Medium Metro',
#  'Santa Rosa': 'Medium Metro',
#  'Sarasota': 'Medium Metro',
#  'Seminole': 'Non-Core',
#  'Suwannee': 'Non-Core',
#  'Taylor': 'Non-Core',
#  'Volusia': 'Medium Metro',
#  'Wakulla': 'Medium Metro',
#  'Walton': 'Large Fringe Metro',
#  'Appling': 'Non-Core',
#  'Atkinson': 'Non-Core',
#  'Bacon': 'Non-Core',
#  'Banks': 'Non-Core',
#  'Barrow': 'Large Fringe Metro',
#  'Bartow': 'Large Fringe Metro',
#  'Ben Hill': 'Micropolitan',
#  'Berrien': 'Small Metro',
#  'Bleckley': 'Non-Core',
#  'Brantley': 'Small Metro',
#  'Brooks': 'Non-Core',
#  'Bryan': 'Micropolitan',
#  'Bulloch': 'Micropolitan',
#  'Burke': 'Non-Core',
#  'Butts': 'Large Fringe Metro',
#  'Camden': 'Micropolitan',
#  'Candler': 'Non-Core',
#  'Catoosa': 'Medium Metro',
#  'Charlton': 'Non-Core',
#  'Chatham': 'Medium Metro',
#  'Chattahoochee': 'Medium Metro',
#  'Chattooga': 'Micropolitan',
#  'Clayton': 'Non-Core',
#  'Clinch': 'Non-Core',
#  'Cobb': 'Large Fringe Metro',
#  'Colquitt': 'Micropolitan',
#  'Cook': 'Non-Core',
#  'Coweta': 'Large Fringe Metro',
#  'Crisp': 'Micropolitan',
#  'Dade': 'Non-Core',
#  'Dawson': 'Micropolitan',
#  'Decatur': 'Non-Core',
#  'Dodge': 'Micropolitan',
#  'Dooly': 'Non-Core',
#  'Dougherty': 'Small Metro',
#  'Early': 'Non-Core',
#  'Echols': 'Small Metro',
#  'Effingham': 'Micropolitan',
#  'Emanuel': 'Non-Core',
#  'Evans': 'Non-Core',
#  'Fannin': 'Non-Core',
#  'Floyd': 'Small Metro',
#  'Forsyth': 'Medium Metro',
#  'Gilmer': 'Non-Core',
#  'Glascock': 'Non-Core',
#  'Glynn': 'Small Metro',
#  'Gordon': 'Micropolitan',
#  'Grady': 'Large Fringe Metro',
#  'Gwinnett': 'Large Fringe Metro',
#  'Habersham': 'Micropolitan',
#  'Hall': 'Non-Core',
#  'Hancock': 'Small Metro',
#  'Haralson': 'Large Fringe Metro',
#  'Harris': 'Large Central Metro',
#  'Hart': 'Non-Core',
#  'Heard': 'Large Fringe Metro',
#  'Irwin': 'Non-Core',
#  'Jasper': 'Non-Core',
#  'Jeff Davis': 'Non-Core',
#  'Jenkins': 'Non-Core',
#  'Jones': 'Small Metro',
#  'Lanier': 'Small Metro',
#  'Laurens': 'Medium Metro',
#  'Long': 'Small Metro',
#  'Lumpkin': 'Non-Core',
#  'McDuffie': 'Medium Metro',
#  'McIntosh': 'Non-Core',
#  'Meriwether': 'Large Fringe Metro',
#  'Mitchell': 'Non-Core',
#  'Murray': 'Non-Core',
#  'Muscogee': 'Medium Metro',
#  'Oconee': 'Micropolitan',
#  'Oglethorpe': 'Small Metro',
#  'Paulding': 'Non-Core',
#  'Peach': 'Small Metro',
#  'Pierce': 'Large Fringe Metro',
#  'Quitman': 'Non-Core',
#  'Rabun': 'Non-Core',
#  'Richmond': 'Non-Core',
#  'Rockdale': 'Large Fringe Metro',
#  'Schley': 'Micropolitan',
#  'Screven': 'Non-Core',
#  'Spalding': 'Large Fringe Metro',
#  'Stephens': 'Non-Core',
#  'Stewart': 'Non-Core',
#  'Talbot': 'Micropolitan',
#  'Taliaferro': 'Non-Core',
#  'Tattnall': 'Non-Core',
#  'Telfair': 'Non-Core',
#  'Terrell': 'Non-Core',
#  'Thomas': 'Non-Core',
#  'Tift': 'Micropolitan',
#  'Toombs': 'Micropolitan',
#  'Towns': 'Non-Core',
#  'Treutlen': 'Non-Core',
#  'Troup': 'Micropolitan',
#  'Turner': 'Small Metro',
#  'Twiggs': 'Small Metro',
#  'Upson': 'Micropolitan',
#  'Ware': 'Micropolitan',
#  'Warren': 'Large Fringe Metro',
#  'Wayne': 'Medium Metro',
#  'Webster': 'Non-Core',
#  'Wheeler': 'Non-Core',
#  'Whitfield': 'Small Metro',
#  'Wilkes': 'Micropolitan',
#  'Wilkinson': 'Non-Core',
#  'Worth': 'Non-Core',
#  'Hawaii': 'Micropolitan',
#  'Honolulu': 'Medium Metro',
#  'Kalawao': 'Small Metro',
#  'Kauai': 'Micropolitan',
#  'Maui': 'Small Metro',
#  'Ada': 'Medium Metro',
#  'Bannock': 'Small Metro',
#  'Bear Lake': 'Non-Core',
#  'Benewah': 'Non-Core',
#  'Bingham': 'Micropolitan',
#  'Blaine': 'Non-Core',
#  'Boise': 'Medium Metro',
#  'Bonner': 'Micropolitan',
#  'Bonneville': 'Small Metro',
#  'Boundary': 'Non-Core',
#  'Camas': 'Micropolitan',
#  'Canyon': 'Medium Metro',
#  'Caribou': 'Non-Core',
#  'Cassia': 'Micropolitan',
#  'Clearwater': 'Non-Core',
#  'Gem': 'Medium Metro',
#  'Gooding': 'Non-Core',
#  'Idaho': 'Non-Core',
#  'Jerome': 'Micropolitan',
#  'Kootenai': 'Small Metro',
#  'Latah': 'Micropolitan',
#  'Lemhi': 'Non-Core',
#  'Lewis': 'Non-Core',
#  'Minidoka': 'Micropolitan',
#  'Nez Perce': 'Small Metro',
#  'Oneida': 'Non-Core',
#  'Owyhee': 'Medium Metro',
#  'Payette': 'Micropolitan',
#  'Power': 'Non-Core',
#  'Shoshone': 'Non-Core',
#  'Teton': 'Micropolitan',
#  'Twin Falls': 'Micropolitan',
#  'Valley': 'Non-Core',
#  'Alexander': 'Medium Metro',
#  'Bond': 'Large Fringe Metro',
#  'Brown': 'Medium Metro',
#  'Bureau': 'Micropolitan',
#  'Cass': 'Non-Core',
#  'Champaign': 'Micropolitan',
#  'Christian': 'Medium Metro',
#  'Clinton': 'Micropolitan',
#  'Coles': 'Micropolitan',
#  'Cumberland': 'Non-Core',
#  'De Witt': 'Small Metro',
#  'DuPage': 'Large Fringe Metro',
#  'Edgar': 'Non-Core',
#  'Edwards': 'Non-Core',
#  'Ford': 'Micropolitan',
#  'Gallatin': 'Micropolitan',
#  'Grundy': 'Non-Core',
#  'Hardin': 'Medium Metro',
#  'Henderson': 'Micropolitan',
#  'Iroquois': 'Non-Core',
#  'Jersey': 'Large Fringe Metro',
#  'Jo Daviess': 'Non-Core',
#  'Kane': 'Non-Core',
#  'Kankakee': 'Small Metro',
#  'Kendall': 'Large Fringe Metro',
#  'Knox': 'Non-Core',
#  'La Salle': 'Non-Core',
#  'Livingston': 'Large Fringe Metro',
#  'McDonough': 'Micropolitan',
#  'McHenry': 'Micropolitan',
#  'McLean': 'Non-Core',
#  'Macoupin': 'Large Fringe Metro',
#  'Mason': 'Micropolitan',
#  'Massac': 'Micropolitan',
#  'Menard': 'Non-Core',
#  'Mercer': 'Micropolitan',
#  'Moultrie': 'Non-Core',
#  'Ogle': 'Micropolitan',
#  'Peoria': 'Medium Metro',
#  'Piatt': 'Small Metro',
#  'Richland': 'Non-Core',
#  'Rock Island': 'Medium Metro',
#  'Sangamon': 'Small Metro',
#  'Schuyler': 'Non-Core',
#  'Stark': 'Medium Metro',
#  'Stephenson': 'Micropolitan',
#  'Tazewell': 'Micropolitan',
#  'Vermilion': 'Small Metro',
#  'Wabash': 'Micropolitan',
#  'Whiteside': 'Micropolitan',
#  'Will': 'Large Fringe Metro',
#  'Williamson': 'Large Fringe Metro',
#  'Winnebago': 'Small Metro',
#  'Woodford': 'Medium Metro',
#  'Allen': 'Small Metro',
#  'Bartholomew': 'Small Metro',
#  'Blackford': 'Non-Core',
#  'Daviess': 'Non-Core',
#  'Dearborn': 'Large Fringe Metro',
#  'Delaware': 'Large Fringe Metro',
#  'Dubois': 'Micropolitan',
#  'Elkhart': 'Small Metro',
#  'Fountain': 'Non-Core',
#  'Gibson': 'Non-Core',
#  'Harrison': 'Micropolitan',
#  'Hendricks': 'Large Fringe Metro',
#  'Huntington': 'Micropolitan',
#  'Jay': 'Non-Core',
#  'Jennings': 'Micropolitan',
#  'Kosciusko': 'Micropolitan',
#  'LaGrange': 'Non-Core',
#  'LaPorte': 'Small Metro',
#  'Miami': 'Medium Metro',
#  'Noble': 'Non-Core',
#  'Ohio': 'Small Metro',
#  'Owen': 'Non-Core',
#  'Parke': 'Non-Core',
#  'Porter': 'Large Fringe Metro',
#  'Posey': 'Medium Metro',
#  'Ripley': 'Non-Core',
#  'Rush': 'Non-Core',
#  'St. Joseph': 'Micropolitan',
#  'Spencer': 'Large Fringe Metro',
#  'Starke': 'Non-Core',
#  'Steuben': 'Micropolitan',
#  'Sullivan': 'Medium Metro',
#  'Switzerland': 'Non-Core',
#  'Tippecanoe': 'Small Metro',
#  'Tipton': 'Large Fringe Metro',
#  'Vanderburgh': 'Medium Metro',
#  'Vermillion': 'Small Metro',
#  'Vigo': 'Small Metro',
#  'Warrick': 'Medium Metro',
#  'Wells': 'Non-Core',
#  'Whitley': 'Micropolitan',
#  'Adair': 'Non-Core',
#  'Allamakee': 'Non-Core',
#  'Appanoose': 'Non-Core',
#  'Audubon': 'Non-Core',
#  'Black Hawk': 'Small Metro',
#  'Bremer': 'Small Metro',
#  'Buchanan': 'Non-Core',
#  'Buena Vista': 'Micropolitan',
#  'Cedar': 'Non-Core',
#  'Cerro Gordo': 'Micropolitan',
#  'Chickasaw': 'Non-Core',
#  'Davis': 'Medium Metro',
#  'Des Moines': 'Micropolitan',
#  'Dickinson': 'Micropolitan',
#  'Dubuque': 'Small Metro',
#  'Emmet': 'Non-Core',
#  'Guthrie': 'Medium Metro',
#  'Ida': 'Non-Core',
#  'Iowa': 'Medium Metro',
#  'Keokuk': 'Non-Core',
#  'Kossuth': 'Non-Core',
#  'Linn': 'Small Metro',
#  'Louisa': 'Non-Core',
#  'Lucas': 'Medium Metro',
#  'Lyon': 'Micropolitan',
#  'Mahaska': 'Micropolitan',
#  'Mills': 'Non-Core',
#  'Monona': 'Non-Core',
#  'Muscatine': 'Micropolitan',
#  "O'Brien": 'Non-Core',
#  'Page': 'Non-Core',
#  'Palo Alto': 'Non-Core',
#  'Plymouth': 'Large Fringe Metro',
#  'Pocahontas': 'Non-Core',
#  'Pottawattamie': 'Medium Metro',
#  'Poweshiek': 'Non-Core',
#  'Ringgold': 'Non-Core',
#  'Sac': 'Non-Core',
#  'Sioux': 'Small Metro',
#  'Story': 'Small Metro',
#  'Tama': 'Non-Core',
#  'Wapello': 'Micropolitan',
#  'Winneshiek': 'Non-Core',
#  'Woodbury': 'Small Metro',
#  'Wright': 'Non-Core',
#  'Anderson': 'Micropolitan',
#  'Atchison': 'Non-Core',
#  'Barber': 'Non-Core',
#  'Barton': 'Non-Core',
#  'Bourbon': 'Medium Metro',
#  'Chase': 'Non-Core',
#  'Chautauqua': 'Micropolitan',
#  'Cloud': 'Non-Core',
#  'Coffey': 'Non-Core',
#  'Comanche': 'Non-Core',
#  'Cowley': 'Micropolitan',
#  'Doniphan': 'Small Metro',
#  'Elk': 'Non-Core',
#  'Ellis': 'Large Fringe Metro',
#  'Ellsworth': 'Non-Core',
#  'Finney': 'Micropolitan',
#  'Geary': 'Micropolitan',
#  'Gove': 'Non-Core',
#  'Gray': 'Micropolitan',
#  'Greeley': 'Non-Core',
#  'Greenwood': 'Micropolitan',
#  'Harper': 'Non-Core',
#  'Harvey': 'Medium Metro',
#  'Haskell': 'Non-Core',
#  'Hodgeman': 'Non-Core',
#  'Jewell': 'Non-Core',
#  'Kearny': 'Micropolitan',
#  'Kingman': 'Medium Metro',
#  'Labette': 'Micropolitan',
#  'Lane': 'Medium Metro',
#  'Leavenworth': 'Large Fringe Metro',
#  'McPherson': 'Non-Core',
#  'Meade': 'Small Metro',
#  'Morris': 'Non-Core',
#  'Morton': 'Small Metro',
#  'Nemaha': 'Non-Core',
#  'Neosho': 'Non-Core',
#  'Ness': 'Non-Core',
#  'Norton': 'Non-Core',
#  'Osage': 'Medium Metro',
#  'Osborne': 'Non-Core',
#  'Ottawa': 'Micropolitan',
#  'Pawnee': 'Medium Metro',
#  'Pottawatomie': 'Micropolitan',
#  'Pratt': 'Non-Core',
#  'Rawlins': 'Non-Core',
#  'Reno': 'Micropolitan',
#  'Republic': 'Non-Core',
#  'Rice': 'Micropolitan',
#  'Riley': 'Small Metro',
#  'Rooks': 'Non-Core',
#  'Seward': 'Medium Metro',
#  'Shawnee': 'Small Metro',
#  'Sheridan': 'Micropolitan',
#  'Sherman': 'Non-Core',
#  'Smith': 'Small Metro',
#  'Stafford': 'Large Fringe Metro',
#  'Stanton': 'Micropolitan',
#  'Stevens': 'Medium Metro',
#  'Sumner': 'Large Fringe Metro',
#  'Trego': 'Non-Core',
#  'Wabaunsee': 'Small Metro',
#  'Wallace': 'Non-Core',
#  'Wichita': 'Small Metro',
#  'Wilson': 'Large Fringe Metro',
#  'Woodson': 'Non-Core',
#  'Wyandotte': 'Large Fringe Metro',
#  'Ballard': 'Micropolitan',
#  'Barren': 'Micropolitan',
#  'Bath': 'Non-Core',
#  'Bell': 'Medium Metro',
#  'Boyd': 'Non-Core',
#  'Boyle': 'Micropolitan',
#  'Bracken': 'Large Fringe Metro',
#  'Breathitt': 'Non-Core',
#  'Breckinridge': 'Non-Core',
#  'Bullitt': 'Large Fringe Metro',
#  'Caldwell': 'Large Fringe Metro',
#  'Calloway': 'Micropolitan',
#  'Campbell': 'Micropolitan',
#  'Carlisle': 'Non-Core',
#  'Carter': 'Small Metro',
#  'Casey': 'Non-Core',
#  'Edmonson': 'Small Metro',
#  'Elliott': 'Non-Core',
#  'Estill': 'Non-Core',
#  'Fleming': 'Non-Core',
#  'Garrard': 'Non-Core',
#  'Graves': 'Micropolitan',
#  'Grayson': 'Non-Core',
#  'Green': 'Medium Metro',
#  'Greenup': 'Medium Metro',
#  'Harlan': 'Non-Core',
#  'Hickman': 'Large Fringe Metro',
#  'Hopkins': 'Micropolitan',
#  'Jessamine': 'Medium Metro',
#  'Kenton': 'Large Fringe Metro',
#  'Knott': 'Non-Core',
#  'Larue': 'Small Metro',
#  'Laurel': 'Micropolitan',
#  'Leslie': 'Non-Core',
#  'Letcher': 'Non-Core',
#  'McCracken': 'Micropolitan',
#  'McCreary': 'Non-Core',
#  'Magoffin': 'Non-Core',
#  'Menifee': 'Micropolitan',
#  'Metcalfe': 'Micropolitan',
#  'Muhlenberg': 'Non-Core',
#  'Nelson': 'Small Metro',
#  'Nicholas': 'Non-Core',
#  'Oldham': 'Medium Metro',
#  'Owsley': 'Non-Core',
#  'Pendleton': 'Non-Core',
#  'Powell': 'Non-Core',
#  'Robertson': 'Small Metro',
#  'Rockcastle': 'Micropolitan',
#  'Rowan': 'Large Fringe Metro',
#  'Simpson': 'Medium Metro',
#  'Todd': 'Non-Core',
#  'Trigg': 'Medium Metro',
#  'Trimble': 'Large Fringe Metro',
#  'Wolfe': 'Non-Core',
#  'Acadia Parish': 'Medium Metro',
#  'Allen Parish': 'Non-Core',
#  'Ascension Parish': 'Medium Metro',
#  'Assumption Parish': 'Non-Core',
#  'Avoyelles Parish': 'Non-Core',
#  'Beauregard Parish': 'Micropolitan',
#  'Bienville Parish': 'Non-Core',
#  'Bossier Parish': 'Medium Metro',
#  'Caddo Parish': 'Medium Metro',
#  'Calcasieu Parish': 'Small Metro',
#  'Caldwell Parish': 'Non-Core',
#  'Cameron Parish': 'Small Metro',
#  'Catahoula Parish': 'Non-Core',
#  'Claiborne Parish': 'Non-Core',
#  'Concordia Parish': 'Micropolitan',
#  'De Soto Parish': 'Medium Metro',
#  'East Baton Rouge Parish': 'Medium Metro',
#  'East Carroll Parish': 'Non-Core',
#  'East Feliciana Parish': 'Medium Metro',
#  'Evangeline Parish': 'Non-Core',
#  'Franklin Parish': 'Non-Core',
#  'Grant Parish': 'Small Metro',
#  'Iberia Parish': 'Medium Metro',
#  'Iberville Parish': 'Medium Metro',
#  'Jackson Parish': 'Non-Core',
#  'Jefferson Parish': 'Large Fringe Metro',
#  'Jefferson Davis Parish': 'Non-Core',
#  'Lafayette Parish': 'Medium Metro',
#  'Lafourche Parish': 'Small Metro',
#  'LaSalle Parish': 'Non-Core',
#  'Lincoln Parish': 'Micropolitan',
#  'Livingston Parish': 'Medium Metro',
#  'Madison Parish': 'Non-Core',
#  'Morehouse Parish': 'Micropolitan',
#  'Natchitoches Parish': 'Micropolitan',
#  'Orleans Parish': 'Large Central Metro',
#  'Ouachita Parish': 'Small Metro',
#  'Plaquemines Parish': 'Large Fringe Metro',
#  'Pointe Coupee Parish': 'Medium Metro',
#  'Rapides Parish': 'Small Metro',
#  'Red River Parish': 'Non-Core',
#  'Richland Parish': 'Non-Core',
#  'Sabine Parish': 'Non-Core',
#  'St. Bernard Parish': 'Large Fringe Metro',
#  'St. Charles Parish': 'Large Fringe Metro',
#  'St. Helena Parish': 'Medium Metro',
#  'St. James Parish': 'Large Fringe Metro',
#  'St. John the Baptist Parish': 'Large Fringe Metro',
#  'St. Landry Parish': 'Micropolitan',
#  'St. Martin Parish': 'Medium Metro',
#  'St. Mary Parish': 'Micropolitan',
#  'St. Tammany Parish': 'Large Fringe Metro',
#  'Tangipahoa Parish': 'Small Metro',
#  'Tensas Parish': 'Non-Core',
#  'Terrebonne Parish': 'Small Metro',
#  'Union Parish': 'Small Metro',
#  'Vermilion Parish': 'Medium Metro',
#  'Vernon Parish': 'Micropolitan',
#  'Washington Parish': 'Micropolitan',
#  'Webster Parish': 'Medium Metro',
#  'West Baton Rouge Parish': 'Medium Metro',
#  'West Carroll Parish': 'Non-Core',
#  'West Feliciana Parish': 'Medium Metro',
#  'Winn Parish': 'Non-Core',
#  'Androscoggin': 'Small Metro',
#  'Aroostook': 'Non-Core',
#  'Kennebec': 'Micropolitan',
#  'Oxford': 'Non-Core',
#  'Penobscot': 'Small Metro',
#  'Piscataquis': 'Non-Core',
#  'Sagadahoc': 'Medium Metro',
#  'Somerset': 'Micropolitan',
#  'Waldo': 'Non-Core',
#  'York': 'Large Fringe Metro',
#  'Allegany': 'Non-Core',
#  'Anne Arundel': 'Large Fringe Metro',
#  'Baltimore': 'Large Fringe Metro',
#  'Calvert': 'Large Fringe Metro',
#  'Caroline': 'Large Fringe Metro',
#  'Cecil': 'Large Fringe Metro',
#  'Charles': 'Large Fringe Metro',
#  'Dorchester': 'Medium Metro',
#  'Frederick': 'Small Metro',
#  'Garrett': 'Non-Core',
#  'Harford': 'Large Fringe Metro',
#  "Prince George's": 'Large Fringe Metro',
#  "Queen Anne's": 'Large Fringe Metro',
#  "St. Mary's": 'Small Metro',
#  'Wicomico': 'Medium Metro',
#  'Worcester': 'Medium Metro',
#  'Baltimore city': 'Large Central Metro',
#  'Barnstable': 'Small Metro',
#  'Berkshire': 'Small Metro',
#  'Bristol': 'Large Fringe Metro',
#  'Dukes': 'Micropolitan',
#  'Essex': 'Non-Core',
#  'Hampden': 'Medium Metro',
#  'Hampshire': 'Small Metro',
#  'Nantucket': 'Non-Core',
#  'Norfolk': 'Large Fringe Metro',
#  'Suffolk': 'Large Fringe Metro',
#  'Alcona': 'Non-Core',
#  'Alger': 'Non-Core',
#  'Allegan': 'Micropolitan',
#  'Alpena': 'Micropolitan',
#  'Antrim': 'Non-Core',
#  'Arenac': 'Non-Core',
#  'Baraga': 'Non-Core',
#  'Barry': 'Non-Core',
#  'Benzie': 'Micropolitan',
#  'Branch': 'Micropolitan',
#  'Charlevoix': 'Non-Core',
#  'Cheboygan': 'Non-Core',
#  'Chippewa': 'Small Metro',
#  'Clare': 'Non-Core',
#  'Eaton': 'Medium Metro',
#  'Genesee': 'Micropolitan',
#  'Gladwin': 'Non-Core',
#  'Gogebic': 'Non-Core',
#  'Grand Traverse': 'Micropolitan',
#  'Gratiot': 'Micropolitan',
#  'Hillsdale': 'Micropolitan',
#  'Houghton': 'Micropolitan',
#  'Huron': 'Micropolitan',
#  'Ingham': 'Medium Metro',
#  'Ionia': 'Micropolitan',
#  'Iosco': 'Non-Core',
#  'Iron': 'Non-Core',
#  'Isabella': 'Micropolitan',
#  'Kalamazoo': 'Medium Metro',
#  'Kalkaska': 'Micropolitan',
#  'Keweenaw': 'Micropolitan',
#  'Lapeer': 'Large Fringe Metro',
#  'Leelanau': 'Micropolitan',
#  'Lenawee': 'Micropolitan',
#  'Luce': 'Non-Core',
#  'Mackinac': 'Non-Core',
#  'Macomb': 'Large Fringe Metro',
#  'Manistee': 'Non-Core',
#  'Marquette': 'Non-Core',
#  'Mecosta': 'Micropolitan',
#  'Menominee': 'Micropolitan',
#  'Midland': 'Small Metro',
#  'Missaukee': 'Micropolitan',
#  'Montcalm': 'Large Fringe Metro',
#  'Montmorency': 'Non-Core',
#  'Muskegon': 'Small Metro',
#  'Newaygo': 'Non-Core',
#  'Oakland': 'Large Fringe Metro',
#  'Oceana': 'Non-Core',
#  'Ogemaw': 'Non-Core',
#  'Ontonagon': 'Non-Core',
#  'Oscoda': 'Non-Core',
#  'Otsego': 'Micropolitan',
#  'Presque Isle': 'Non-Core',
#  'Roscommon': 'Non-Core',
#  'Saginaw': 'Small Metro',
#  'Sanilac': 'Non-Core',
#  'Schoolcraft': 'Non-Core',
#  'Shiawassee': 'Micropolitan',
#  'Tuscola': 'Non-Core',
#  'Washtenaw': 'Medium Metro',
#  'Wexford': 'Micropolitan',
#  'Aitkin': 'Non-Core',
#  'Anoka': 'Large Fringe Metro',
#  'Becker': 'Non-Core',
#  'Beltrami': 'Micropolitan',
#  'Big Stone': 'Non-Core',
#  'Blue Earth': 'Small Metro',
#  'Carlton': 'Medium Metro',
#  'Carver': 'Large Fringe Metro',
#  'Chisago': 'Large Fringe Metro',
#  'Cottonwood': 'Non-Core',
#  'Crow Wing': 'Micropolitan',
#  'Dakota': 'Small Metro',
#  'Faribault': 'Non-Core',
#  'Fillmore': 'Non-Core',
#  'Freeborn': 'Micropolitan',
#  'Goodhue': 'Micropolitan',
#  'Hennepin': 'Large Central Metro',
#  'Hubbard': 'Non-Core',
#  'Isanti': 'Large Fringe Metro',
#  'Itasca': 'Non-Core',
#  'Kanabec': 'Non-Core',
#  'Kandiyohi': 'Micropolitan',
#  'Kittson': 'Non-Core',
#  'Koochiching': 'Non-Core',
#  'Lac qui Parle': 'Non-Core',
#  'Lake of the Woods': 'Non-Core',
#  'Le Sueur': 'Large Fringe Metro',
#  'McLeod': 'Micropolitan',
#  'Mahnomen': 'Non-Core',
#  'Meeker': 'Non-Core',
#  'Mille Lacs': 'Large Fringe Metro',
#  'Morrison': 'Non-Core',
#  'Mower': 'Micropolitan',
#  'Nicollet': 'Small Metro',
#  'Nobles': 'Micropolitan',
#  'Norman': 'Non-Core',
#  'Olmsted': 'Small Metro',
#  'Otter Tail': 'Micropolitan',
#  'Pennington': 'Small Metro',
#  'Pine': 'Non-Core',
#  'Pipestone': 'Non-Core',
#  'Ramsey': 'Non-Core',
#  'Red Lake': 'Non-Core',
#  'Redwood': 'Non-Core',
#  'Renville': 'Micropolitan',
#  'Rock': 'Small Metro',
#  'Roseau': 'Non-Core',
#  'St. Louis': 'Large Fringe Metro',
#  'Sherburne': 'Large Fringe Metro',
#  'Sibley': 'Large Fringe Metro',
#  'Stearns': 'Small Metro',
#  'Steele': 'Non-Core',
#  'Swift': 'Non-Core',
#  'Traverse': 'Non-Core',
#  'Wabasha': 'Small Metro',
#  'Wadena': 'Non-Core',
#  'Waseca': 'Non-Core',
#  'Watonwan': 'Non-Core',
#  'Wilkin': 'Micropolitan',
#  'Winona': 'Micropolitan',
#  'Yellow Medicine': 'Non-Core',
#  'Alcorn': 'Micropolitan',
#  'Amite': 'Micropolitan',
#  'Attala': 'Non-Core',
#  'Bolivar': 'Micropolitan',
#  'Claiborne': 'Non-Core',
#  'Coahoma': 'Micropolitan',
#  'Copiah': 'Medium Metro',
#  'Forrest': 'Small Metro',
#  'George': 'Non-Core',
#  'Grenada': 'Micropolitan',
#  'Hinds': 'Medium Metro',
#  'Humphreys': 'Non-Core',
#  'Issaquena': 'Non-Core',
#  'Itawamba': 'Micropolitan',
#  'Jefferson Davis': 'Non-Core',
#  'Kemper': 'Micropolitan',
#  'Leake': 'Non-Core',
#  'Leflore': 'Micropolitan',
#  'Neshoba': 'Non-Core',
#  'Noxubee': 'Non-Core',
#  'Oktibbeha': 'Micropolitan',
#  'Panola': 'Non-Core',
#  'Pearl River': 'Micropolitan',
#  'Pontotoc': 'Micropolitan',
#  ...}

# %% [markdown]
# ##### Importação do dataset sobre limites de velocidade

# %%
# import maximal speed limits by state
speed_limits = pd.read_excel('speed_limit_state.xlsx')
speed_limits = speed_limits.drop(['Freeway (trucks)','Freeway (urban)','Divided (rural)','Undivided (rural)','Residential'], axis=1)

speed_limits = speed_limits.rename(columns={"State or territory": "State", "Freeway (rural)":"Max Speed Limit (mph)"})

# List of all the US States
us_states_list = ["Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"]

# Reformat all the rows in the dataset
for i in range(len(speed_limits.index)):
    if(not pd.isna(speed_limits.loc[i]["State"])):
        speed_limits.at[i, "State"] = re.sub('[^a-z A-Z]+', '', speed_limits.loc[i]["State"])
        speed_limits.at[i, "State"] = speed_limits.loc[i]["State"].replace('\t','')
    if(not pd.isna(speed_limits.loc[i]["Max Speed Limit (mph)"])):
        speed_limits.at[i, "Max Speed Limit (mph)"] = re.sub('\(.*', '', speed_limits.loc[i]["Max Speed Limit (mph)"])

# Filter only the US States
for i in range(len(speed_limits.index)):
    if(speed_limits.loc[i]["State"] not in us_states_list):
        speed_limits = speed_limits.drop(i)
    
# Reset the index
speed_limits = speed_limits.reset_index(drop=True)

speed_limits["Max Speed Limit (mph)"] = speed_limits['Max Speed Limit (mph)'].apply(lambda x: (x[:-4])[-3:])
speed_limits["Max Speed Limit (mph)"] = speed_limits['Max Speed Limit (mph)'].apply(lambda x: int(x))
speed_limits.at[36, "Max Speed Limit (mph)"] = 70

speed_limits = speed_limits.sort_values(by=['Max Speed Limit (mph)'], ascending=False)

speed_limits.loc[speed_limits['Max Speed Limit (mph)'].apply(lambda x : x < 70), 'DiscretizeSpeedLimit'] = 'Low'
speed_limits.loc[speed_limits['Max Speed Limit (mph)'].apply(lambda x : (x >= 70) & (x < 80)), 'DiscretizeSpeedLimit'] = 'Medium'
speed_limits.loc[speed_limits['Max Speed Limit (mph)'].apply(lambda x : (x >= 80)), 'DiscretizeSpeedLimit'] = 'High'

speed_dict = pd.Series(speed_limits['DiscretizeSpeedLimit'].values,index=speed_limits['State']).to_dict()
speed_dict
# Out:
# {'Texas': 'High',
#  'Montana': 'High',
#  'Idaho': 'High',
#  'Utah': 'High',
#  'South Dakota': 'High',
#  'Nevada': 'High',
#  'Wyoming': 'High',
#  'Maine': 'Medium',
#  'Michigan': 'Medium',
#  'North Dakota': 'Medium',
#  'Colorado': 'Medium',
#  'Nebraska': 'Medium',
#  'Arizona': 'Medium',
#  'Arkansas': 'Medium',
#  'Kansas': 'Medium',
#  'Oklahoma': 'Medium',
#  'Louisiana': 'Medium',
#  'New Mexico': 'Medium',
#  'Ohio': 'Medium',
#  'Oregon': 'Medium',
#  'Pennsylvania': 'Medium',
#  'New Hampshire': 'Medium',
#  'South Carolina': 'Medium',
#  'California': 'Medium',
#  'Tennessee': 'Medium',
#  'Virginia': 'Medium',
#  'Washington': 'Medium',
#  'West Virginia': 'Medium',
#  'Wisconsin': 'Medium',
#  'North Carolina': 'Medium',
#  'Alabama': 'Medium',
#  'Maryland': 'Medium',
#  'Indiana': 'Medium',
#  'Florida': 'Medium',
#  'Georgia': 'Medium',
#  'Missouri': 'Medium',
#  'Mississippi': 'Medium',
#  'Minnesota': 'Medium',
#  'Illinois': 'Medium',
#  'Kentucky': 'Medium',
#  'Iowa': 'Medium',
#  'Connecticut': 'Low',
#  'Vermont': 'Low',
#  'New York': 'Low',
#  'New Jersey': 'Low',
#  'Massachusetts': 'Low',
#  'Rhode Island': 'Low',
#  'Alaska': 'Low',
#  'Delaware': 'Low',
#  'Hawaii': 'Low'}

# %% [markdown]
# ### Tratamento do dataset original
#
# #### Tratamento de dados nulos/incompletos
#
# * As linhas que têm valores relativos ao twilight e período do dia vazios serão removidas;
# * As linhas que não têm informação relativa à cidade na qual o acidente ocorre também serão                removidas;
# * Os códigos TMC (Traffic Message Channel) que sejam nulos serão identificados com um número fora do domínio dos códigos existentes e não vão ser relevantes para possíveis interrogações;
# * Definição de valores para dados meteorológicos nulos será feita com base na média de valores em cada atributo, ao nível da cidade, na respetiva semana em que ocorreu o acidente (\*);
# * O preenchimento de dados quem não contêm fuso horário será feito através da correspondência entre o estado onde o acidente ocorreu e o fuso horário no qual se encontra.
#
# #### Remoção de colunas
# * 'Source',
# * 'Start_Lat',
# * 'Country',
# * 'Start_Lng',
# * 'End_Lat',
# * 'End_Lng',
# * 'Description',
# * 'Number',
# * 'Side',
# * 'Zipcode',
# * 'Airport_Code',
# * 'Weather_Timestamp',
# * 'Pressure(in)',
# * 'Wind_Chill(F)'

# %%
us_acidents.columns
# Out:
# Index(['ID', 'Source', 'TMC', 'Severity', 'Start_Time', 'End_Time',
#        'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)',
#        'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
#        'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
#        'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
# drop unuseful information/columns
us_acidents = us_acidents.drop(['Source','Start_Lat','Country','Start_Lng','End_Lat','End_Lng','Description','Number','Side','Zipcode','Airport_Code','Weather_Timestamp', 'Pressure(in)', 'Wind_Chill(F)'], axis=1)

# %%
# delete rows with non avaliable values
us_acidents = us_acidents.dropna(subset=['City', 'Civil_Twilight','Nautical_Twilight','Astronomical_Twilight']).reset_index(drop=True)

# %%
# Replace TMC values with out-of-range values, not used in OLAP.
us_acidents['TMC'].fillna(-1, inplace=True)

# %%
# Replace empty timezone values with the correspondent ones from each state
timezone_df = us_acidents[["State", "Timezone"]].drop_duplicates(subset="State")
timezone_dict = pd.Series(timezone_df['Timezone'].values,index=timezone_df['State']).to_dict()

us_acidents['Timezone'].fillna(us_acidents['State'].map(timezone_dict), inplace=True)

# %% [markdown]
# #### POI Dimension

# %%
# Add POI_Key
us_acidents.insert(us_acidents.columns.get_loc("Amenity"), 'POI_Key', range(1, 1 + len(us_acidents)))
us_acidents['POI_Key'].unique()
# Out:
# array([      1,       2,       3, ..., 2974240, 2974241, 2974242])

# %%
poi_dimension = us_acidents.loc[:,'POI_Key':'Turning_Loop'] # create poi dataset
poi_dimension.columns
# Out:
# Index(['POI_Key', 'Amenity', 'Bump', 'Crossing', 'Give_Way', 'Junction',
#        'No_Exit', 'Railway', 'Roundabout', 'Station', 'Stop',
#        'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop'],
#       dtype='object')

# %%
poi_dimension[:5]
# Out:
#    POI_Key  Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  Railway  \
# 0        1    False  False     False     False     False    False    False
# 1        2    False  False     False     False     False    False    False
# 2        3    False  False     False     False     False    False    False
# 3        4    False  False     False     False     False    False    False
# 4        5    False  False     False     False     False    False    False
#
#    Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  Turning_Loop
# 0       False    False  False            False           False         False
# 1       False    False  False            False           False         False
# 2       False    False  False            False            True         False
# 3       False    False  False            False           False         False
# 4       False    False  False            False            True         False

# %%
#drop unwanted data from the us_acidents dataframe
us_acidents = us_acidents.drop(['Amenity', 'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop'], axis=1)

# %%
# State of Accidents Dataset, now with POI_Key
us_acidents.columns
# Out:
# Index(['ID', 'TMC', 'Severity', 'Start_Time', 'End_Time', 'Distance(mi)',
#        'Street', 'City', 'County', 'State', 'Timezone', 'Temperature(F)',
#        'Humidity(%)', 'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'POI_Key', 'Sunrise_Sunset',
#        'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight'],
#       dtype='object')

# %% [markdown]
# #### Location Dimension

# %% [markdown]
# ##### Inserção de Chave

# %%
us_acidents.insert(us_acidents.columns.get_loc("Street"), 'LocationKey', range(1, 1 + len(us_acidents))) # add location_key

# %% [markdown]
# ##### Definição dos atributos de região

# %%
us_acidents['State'].unique()
# Out:
# array(['OH', 'WV', 'CA', 'FL', 'GA', 'SC', 'NE', 'IA', 'IL', 'MO', 'WI',
#        'IN', 'MI', 'NJ', 'NY', 'CT', 'MA', 'RI', 'NH', 'PA', 'KY', 'MD',
#        'VA', 'DC', 'DE', 'TX', 'WA', 'OR', 'AL', 'NC', 'MN', 'OK', 'LA',
#        'TN', 'UT', 'CO', 'AZ', 'NV', 'KS', 'MS', 'NM', 'ME', 'AR', 'WY',
#        'VT', 'ID', 'ND', 'MT', 'SD'], dtype=object)

# %%
# Eliminar??
# Muitos dados que temos não incluem este estado - Não é um estado
print(us_acidents.loc[us_acidents["State"] == 'DC']["State"])
us_acidents = us_acidents[us_acidents["State"] != 'DC']
# Out:
# 228611     DC
# 228631     DC
# 228635     DC
# 228639     DC
# 228671     DC
#            ..
# 2967946    DC
# 2967947    DC
# 2970177    DC
# 2970178    DC
# 2971762    DC
# Name: State, Length: 3634, dtype: object

# %%
replace_values = {'OH':'Ohio', 'WV':'West Virginia', 'CA': 'California', 'FL': 'Florida', 'GA': 'Georgia', 'SC':'South Carolina', 'NE': 'Nebraska', 'IA': 'Iowa', 'IL': 'Illinois', 'MO': 'Missouri', 'WI': 'Wisconsin',
       'IN': 'Indiana', 'MI': 'Michigan', 'NJ': 'New Jersey', 'NY': 'New York', 'CT': 'Connecticut', 'MA': 'Massachusetts', 'RI': 'Rhode Island', 'NH': 'New Hampshire', 'PA': 'Pennsylvania', 'KY': 'Kentucky', 'MD': 'Maryland',
       'VA': 'Virginia', 'DE': 'Delaware', 'TX':'Texas', 'WA': 'Washington', 'OR': 'Oregon', 'AL': 'Alabama', 'NC': 'North Carolina', 'MN': 'Minnesota', 'OK': 'Oklahoma', 'LA': 'Louisiana',
   'TN': 'Tennessee', 'UT': 'Utah', 'CO': 'Colorado', 'AZ': 'Arizona', 'NV': 'Nevada', 'KS': 'Kansas', 'MS': 'Mississippi', 'NM': 'New Mexico', 'ME': 'Maine', 'AR': 'Arkansas', 'WY': 'Wyoming','VT': 'Vermont', 'ID': 'Idaho', 'ND': 'North Dakota', 'MT': 'Montana', 'SD': 'South Dakota'}

# %%
us_acidents = us_acidents.replace({"State": replace_values})

# %%
# https://en.wikipedia.org/wiki/List_of_regions_of_the_United_States#Census_Bureau-designated_regions_and_divisions
## define subregion
def sub_region(state):
    new_england = ['Connecticut', 'Maine', 'Massachusetts', 'New Hampshire', 'Rhode Island', 'Vermont']
    mid_atlantic = ['New Jersey', 'New York','Pennsylvania']
    east_north_central = ['Illinois', 'Indiana', 'Michigan', 'Ohio', 'Wisconsin']
    west_north_central = ['Iowa','Kansas','Minnesota','Missouri','Nebraska','North Dakota','South Dakota']
    south_atlantic = ['Delaware','Florida','Georgia','Maryland','North Carolina','South Carolina','Virginia','West Virginia']
    east_south_central = ['Alabama','Kentucky','Mississippi','Tennessee']
    west_south_central = ['Arkansas','Louisiana','Oklahoma','Texas']
    mountain = ['Arizona','Colorado','Idaho','Montana','Nevada','New Mexico','Utah','Wyoming']
    pacific = ['Alaska','California','Hawaii','Oregon','Washington']
    if state in new_england:
        return 'New England'
    elif state in mid_atlantic:
        return 'Mid Atlantic'
    elif state in east_north_central:
        return 'East North Central'
    elif state in west_north_central:
        return 'West North Central'
    elif state in south_atlantic:
        return 'South Atlantic'
    elif state in east_south_central:
        return 'East South Central'
    elif state in west_south_central:
        return 'West South Central'
    elif state in mountain:
        return 'Mountain'
    elif state in pacific:
        return 'Pacific'
    else:
        return 'algo de errado'

#define region
def region(state):
    northeast = ['Connecticut', 'Maine', 'Massachusetts', 'New Hampshire', 'Rhode Island', 'Vermont', 'New Jersey', 'New York','Pennsylvania']
    midwest = ['Illinois', 'Indiana', 'Michigan', 'Ohio', 'Wisconsin', 'Iowa','Kansas','Minnesota','Missouri','Nebraska','North Dakota','South Dakota']
    south = ['Delaware','Florida','Georgia','Maryland','North Carolina','South Carolina','Virginia','District of Columbia','West Virginia', 'Alabama','Kentucky','Mississippi','Tennessee', 'Arkansas','Louisiana','Oklahoma','Texas']
    west = ['Arizona','Colorado','Idaho','Montana','Nevada','New Mexico','Utah','Wyoming', 'Alaska','California','Hawaii','Oregon','Washington']
    if state in northeast:
        return 'Northeast'
    elif state in midwest:
        return 'Midwest'
    elif state in south:
        return 'South'
    elif state in west:
        return 'West'
    else:
        return 'algo de errado'

# %% [markdown]
# ##### Inserção dos atributos Região e Sub-Região

# %%
# add Region
us_acidents.insert(us_acidents.columns.get_loc("Timezone"), 'Region', us_acidents['State'].apply(lambda x: region(x)))
us_acidents['Region'].value_counts()
# Out:
# South        1249803
# West          956541
# Midwest       410135
# Northeast     354129
# Name: Region, dtype: int64

# %%
# add subregion
us_acidents.insert(us_acidents.columns.get_loc("Timezone"), 'Subregion', us_acidents['State'].apply(lambda x: sub_region(x)))
us_acidents['Subregion'].value_counts()
# Out:
# Pacific               795405
# South Atlantic        726474
# West South Central    403589
# East North Central    278556
# Mid Atlantic          278115
# Mountain              161136
# West North Central    131579
# East South Central    119740
# New England            76014
# Name: Subregion, dtype: int64

# %% [markdown]
# ##### Inserção de atributo AlcoholConsumptionRate

# %%
us_acidents["AlcoholConsumptionRate"] = us_acidents["State"].map(alcohol_dict)

# %%
us_acidents['AlcoholConsumptionRate'].value_counts()
# Out:
# Medium       2161400
# High          555008
# Low           242702
# Very High      11498
# Name: AlcoholConsumptionRate, dtype: int64

# %% [markdown]
# #### Inserção do atributo NumberVehicleRegistrations

# %%
us_acidents["VehicleRegistrations"] = us_acidents["State"].map(vehicle_dict)

us_acidents['VehicleRegistrations'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-4f3bc312da52> in <module>
# ----> 1 us_acidents["VehicleRegistrations"] = us_acidents["State"].map(vehicle_dict)
#       2
#       3 us_acidents['VehicleRegistrations'].value_counts()
#
# NameError: name 'vehicle_dict' is not defined

# %% [markdown]
# #### Inserção do atributo UrbanRuralClassification

# %%
#Add Rate
us_acidents["CountyUrbanRuralClass"] = us_acidents["County"].map(urban_dict)

#~81000 rows dropped - Errors in County, only with manual correction allowed
us_acidents = us_acidents[us_acidents["CountyUrbanRuralClass"].notna()]

us_acidents['CountyUrbanRuralClass'].value_counts()
# Out:
# Large Central Metro    1114034
# Non-Core                543850
# Medium Metro            438121
# Large Fringe Metro      425005
# Micropolitan            185173
# Small Metro             149366
# Name: CountyUrbanRuralClass, dtype: int64

# %% [markdown]
# #### Inserção do atributo MaximumSpeedLimit

# %%
us_acidents["StateMaxSpeedLimit"] = us_acidents["State"].map(vehicle_dict)

us_acidents['StateMaxSpeedLimit'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-1277a32fa6df> in <module>
# ----> 1 us_acidents["StateMaxSpeedLimit"] = us_acidents["State"].map(vehicle_dict)
#       2
#       3 us_acidents['StateMaxSpeedLimit'].value_counts()
#
# NameError: name 'vehicle_dict' is not defined

# %% [markdown]
# TBD:
# * MoonCalendar

# %% [markdown]
# #### Date Dimension

# %% [markdown]
# ##### Conversão dos registos Start_Time e End_Time para timestamp

# %%
# convert to timestamp data 
us_acidents["Start_Time"]= pd.to_datetime(us_acidents["Start_Time"])

# convert to timestamp data type
us_acidents["End_Time"]= pd.to_datetime(us_acidents["End_Time"])

# %% [markdown]
# ##### Inserção de Chave

# %%
us_acidents.insert(us_acidents.columns.get_loc("Start_Time"), 'date_Key', range(1, 1 + len(us_acidents))) # add date_key

# %% [markdown]
# ##### Inserção dos atributos StartDay, StartMonth e StartYear

# %%
us_acidents.insert(us_acidents.columns.get_loc("End_Time"), 'StartDay', us_acidents['Start_Time'].apply(lambda x: x.day))
us_acidents.insert(us_acidents.columns.get_loc("End_Time"), 'StartMonth', us_acidents['Start_Time'].apply(lambda x: x.month_name()))
us_acidents.insert(us_acidents.columns.get_loc("End_Time"), 'StartYear', us_acidents['Start_Time'].apply(lambda x: x.year))

# %%
us_acidents[['Start_Time','StartDay','StartMonth','StartYear']].head(5)
# Out:
#            Start_Time  StartDay StartMonth  StartYear
# 0 2016-02-08 05:46:00         8   February       2016
# 1 2016-02-08 06:07:59         8   February       2016
# 2 2016-02-08 06:49:27         8   February       2016
# 3 2016-02-08 07:23:34         8   February       2016
# 4 2016-02-08 07:39:07         8   February       2016

# %% [markdown]
# ##### Inserção dos atributos EndDay, EndMonth e EndYear

# %%
us_acidents.insert(us_acidents.columns.get_loc("Distance(mi)"), 'EndDay', us_acidents['End_Time'].apply(lambda x: x.day)) 
us_acidents.insert(us_acidents.columns.get_loc("Distance(mi)"), 'EndMonth', us_acidents['End_Time'].apply(lambda x: x.month_name())) 
us_acidents.insert(us_acidents.columns.get_loc("Distance(mi)"), 'EndYear', us_acidents['End_Time'].apply(lambda x: x.year))

# %%
us_acidents[['End_Time','EndDay','EndMonth','EndYear']].tail(5)
# Out:
#                    End_Time  EndDay EndMonth  EndYear
# 2974237 2019-08-23 18:32:01      23   August     2019
# 2974238 2019-08-23 19:38:23      23   August     2019
# 2974239 2019-08-23 19:28:49      23   August     2019
# 2974240 2019-08-23 19:29:42      23   August     2019
# 2974241 2019-08-23 19:21:31      23   August     2019

# %% [markdown]
# ##### Inserção do atributo DayofWeek

# %%
us_acidents.insert(us_acidents.columns.get_loc("Distance(mi)"), 'DayofWeek', us_acidents['Start_Time'].apply(lambda x: x.day_name())) # add DayofWeek

# %%
us_acidents[['Start_Time','DayofWeek']].tail(5)
# Out:
#                  Start_Time DayofWeek
# 2974237 2019-08-23 18:03:25    Friday
# 2974238 2019-08-23 19:11:30    Friday
# 2974239 2019-08-23 19:00:21    Friday
# 2974240 2019-08-23 19:00:21    Friday
# 2974241 2019-08-23 18:52:06    Friday

# %% [markdown]
# ##### Inserção do atributo Weekdayweekend

# %%
weekdaysweekend_dict = {'Monday':"Week Day",'Tuesday':"Week Day",'Wednesday':"Week Day",'Thursday':"Week Day",'Friday':"Week Day", 'Saturday':"Weekend",'Sunday':"Weekend"}

# %%
us_acidents["WeekdayWeekend"] = us_acidents["DayofWeek"].map(weekdaysweekend_dict)
us_acidents['WeekdayWeekend'].value_counts()
# Out:
# Week Day    2542471
# Weekend      313078
# Name: WeekdayWeekend, dtype: int64

# %% [markdown]
# ##### Inserção dos atributos Quarter (trimester) e WeekNumber

# %%
us_acidents.insert(us_acidents.columns.get_loc("Distance(mi)"), 'Quarter', us_acidents['Start_Time'].apply(lambda x: x.quarter)) # add Quarter
us_acidents.insert(us_acidents.columns.get_loc("Distance(mi)"), 'WeekNumber', us_acidents['Start_Time'].apply(lambda x: x.weekofyear)) # add WeekNumber
us_acidents[['Start_Time','Quarter','WeekNumber']].tail(5)
# Out:
#                  Start_Time  Quarter  WeekNumber
# 2974237 2019-08-23 18:03:25        3          34
# 2974238 2019-08-23 19:11:30        3          34
# 2974239 2019-08-23 19:00:21        3          34
# 2974240 2019-08-23 19:00:21        3          34
# 2974241 2019-08-23 18:52:06        3          34

# %% [markdown]
# ##### Inserção do atributo Holiday

# %%
federal_holidays = pd.read_csv('us_federal_hol.csv', delimiter=';')
federal_holidays["date"]= pd.to_datetime(federal_holidays["date"]).dt.date
federal_holidays.head(5)
# Out:
#          date                   holiday  \
# 0  2016-01-01            New Year's Day
# 1  2016-01-18  3tin Luther King Jr. Day
# 2  2016-02-15           Presidents' Day
# 3  2016-05-30              Memorial Day
# 4  2016-04-07          Independence Day
#
#                                    exceptions
# 0
# 1
# 2  DE, GA, IA, IN, KS, KY, LA, NC, NM, RI, WI
# 3
# 4

# %%
holidays_dict = pd.Series(federal_holidays['holiday'].values,index=federal_holidays['date']).to_dict()
holidays_dict
# Out:
# {datetime.date(2016, 1, 1): "New Year's Day",
#  datetime.date(2016, 1, 18): '3tin Luther King Jr. Day',
#  datetime.date(2016, 2, 15): "Presidents' Day",
#  datetime.date(2016, 5, 30): 'Memorial Day',
#  datetime.date(2016, 4, 7): 'Independence Day',
#  datetime.date(2016, 5, 9): 'Labor Day',
#  datetime.date(2016, 10, 10): 'Columbus Day',
#  datetime.date(2016, 11, 11): 'Veterans Day',
#  datetime.date(2016, 11, 24): 'Thanksgiving Day',
#  datetime.date(2016, 12, 25): 'Christmas Day',
#  datetime.date(2016, 12, 26): 'Christmas Day observed',
#  datetime.date(2017, 1, 1): "New Year's Day",
#  datetime.date(2017, 2, 1): "New Year's Day observed",
#  datetime.date(2017, 1, 16): '3tin Luther King Jr. Day',
#  datetime.date(2017, 2, 20): "Presidents' Day",
#  datetime.date(2017, 5, 29): 'Memorial Day',
#  datetime.date(2017, 4, 7): 'Independence Day',
#  datetime.date(2017, 4, 9): 'Labor Day',
#  datetime.date(2017, 9, 10): 'Columbus Day',
#  datetime.date(2017, 10, 11): 'Veterans Day observed',
#  datetime.date(2017, 11, 11): 'Veterans Day',
#  datetime.date(2017, 11, 23): 'Thanksgiving Day',
#  datetime.date(2017, 12, 25): 'Christmas Day',
#  datetime.date(2018, 1, 1): "New Year's Day",
#  datetime.date(2018, 1, 15): '3tin Luther King Jr. Day',
#  datetime.date(2018, 2, 19): "Presidents' Day",
#  datetime.date(2018, 5, 28): 'Memorial Day',
#  datetime.date(2018, 4, 7): 'Independence Day',
#  datetime.date(2018, 3, 9): 'Labor Day',
#  datetime.date(2018, 8, 10): 'Columbus Day',
#  datetime.date(2018, 11, 11): 'Veterans Day',
#  datetime.date(2018, 12, 11): 'Veterans Day observed',
#  datetime.date(2018, 11, 22): 'Thanksgiving Day',
#  datetime.date(2018, 12, 24): 'Christmas Eve',
#  datetime.date(2018, 12, 25): 'Christmas Day',
#  datetime.date(2019, 1, 1): "New Year's Day",
#  datetime.date(2019, 1, 21): '3tin Luther King Jr. Day',
#  datetime.date(2019, 2, 18): "Presidents' Day",
#  datetime.date(2019, 5, 27): 'Memorial Day',
#  datetime.date(2019, 4, 7): 'Independence Day',
#  datetime.date(2019, 2, 9): 'Labor Day',
#  datetime.date(2019, 10, 14): 'Columbus Day',
#  datetime.date(2019, 11, 11): 'Veterans Day',
#  datetime.date(2019, 11, 28): 'Thanksgiving Day',
#  datetime.date(2019, 12, 24): 'Christmas Eve',
#  datetime.date(2019, 12, 25): 'Christmas Day'}

# %%
us_acidents["holidays"] = us_acidents["Start_Time"].dt.date.map(holidays_dict)
us_acidents["holidays"] = us_acidents["holidays"].fillna('Not Holiday')
us_acidents["holidays"].value_counts()
# Out:
# Not Holiday                 2785889
# Columbus Day                   8367
# Veterans Day                   7582
# Presidents' Day                7090
# 3tin Luther King Jr. Day       6873
# Veterans Day observed          6768
# Thanksgiving Day               5769
# Labor Day                      5373
# Independence Day               5176
# Christmas Eve                  4455
# Memorial Day                   4222
# Christmas Day                  2955
# New Year's Day observed        2318
# New Year's Day                 2150
# Christmas Day observed          562
# Name: holidays, dtype: int64

# %% [markdown]
# ##### Inserção do atributo WorkDay

# %%
lista_feriados = []
for i in range(len(us_acidents[['holidays','WeekdayWeekend']])):
    if (us_acidents['holidays'].iloc[i]!='Not Holiday') or (us_acidents['WeekdayWeekend'].iloc[i]=='Week End'):
        lista_feriados.append('non working day') 
    else:
        lista_feriados.append('working day')

# %%
us_acidents['WorkDay'] = pd.Series(lista_feriados).values

# %%
us_acidents[us_acidents['WorkDay']=='non working day'].tail(5)
# Out:
#                 ID  TMC  Severity  date_Key          Start_Time  StartDay  \
# 2925082  A-2925199 -1.0         2   2807781 2019-05-27 17:48:47        27
# 2925083  A-2925200 -1.0         2   2807782 2019-05-27 17:48:47        27
# 2925084  A-2925201 -1.0         4   2807783 2019-05-27 18:19:32        27
# 2925085  A-2925202 -1.0         3   2807784 2019-05-27 19:14:17        27
# 2925480  A-2925597 -1.0         2   2808150 2019-05-27 23:33:47        27
#
#         StartMonth  StartYear            End_Time  EndDay  ...  POI_Key  \
# 2925082        May       2019 2019-05-27 18:16:12      27  ...  2925083
# 2925083        May       2019 2019-05-27 18:16:12      27  ...  2925084
# 2925084        May       2019 2019-05-27 23:08:59      27  ...  2925085
# 2925085        May       2019 2019-05-27 19:42:13      27  ...  2925086
# 2925480        May       2019 2019-05-28 00:03:20      28  ...  2925481
#
#          Sunrise_Sunset Civil_Twilight  Nautical_Twilight  \
# 2925082             Day            Day                Day
# 2925083             Day            Day                Day
# 2925084             Day            Day                Day
# 2925085             Day            Day                Day
# 2925480           Night          Night              Night
#
#          Astronomical_Twilight  AlcoholConsumptionRate  CountyUrbanRuralClass  \
# 2925082                    Day                  Medium            Small Metro
# 2925083                    Day                  Medium            Small Metro
# 2925084                    Day                  Medium    Large Central Metro
# 2925085                    Day                  Medium    Large Central Metro
# 2925480                    Day                  Medium     Large Fringe Metro
#
#         WeekdayWeekend      holidays          WorkDay
# 2925082       Week Day  Memorial Day  non working day
# 2925083       Week Day  Memorial Day  non working day
# 2925084       Week Day  Memorial Day  non working day
# 2925085       Week Day  Memorial Day  non working day
# 2925480       Week Day  Memorial Day  non working day
#
# [5 rows x 41 columns]

# %% [markdown]
# ##### Inserção do atributo School Break

# %%
school_holidays = pd.read_csv('school_holidays.csv', delimiter=';')
school_holidays["Start"]= pd.to_datetime(school_holidays["Start"])
school_holidays["End"]= pd.to_datetime(school_holidays["End"])

# %%
us_acidents.insert(us_acidents.columns.get_loc("Distance(mi)"), 'SchoolBreak', 'Classes')

# %%
for j in range(len(school_holidays['Start'])):
    filtro = (us_acidents['Start_Time'] >= school_holidays["Start"][j]) & (us_acidents['Start_Time'] <= school_holidays["End"][j])
    us_acidents['SchoolBreak'].loc[filtro]= 'No Classes'
# Out:
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
us_acidents['SchoolBreak'].value_counts()
# Out:
# Classes       2240400
# No Classes     615149
# Name: SchoolBreak, dtype: int64

# %% [markdown]
# >> Falta moon calendar

# %%
us_acidents.insert(us_acidents.columns.get_loc("Distance(mi)"), 'MoonCalendar', range(1, 1 + len(us_acidents))) # add MoonCalendar --->> Não concluído

# %% [markdown]
# #### LocalTime Dimension

# %% [markdown]
# #### StandardTime Dimension

# %% [markdown]
# #### Weather Dimension
